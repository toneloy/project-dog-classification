# %% [markdown]
# # Convolutional Neural Networks
#
# ## Project: Write an Algorithm for a Dog Identification App
#
# ---
#
# In this notebook, some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this project. You will not need to modify the included code beyond what is requested. Sections that begin with **'(IMPLEMENTATION)'** in the header indicate that the following block of code will require additional functionality which you must provide. Instructions will be provided for each section, and the specifics of the implementation are marked in the code block with a 'TODO' statement. Please be sure to read the instructions carefully!
#
# > **Note**: Once you have completed all of the code implementations, you need to finalize your work by exporting the Jupyter Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You can then export the notebook by using the menu above and navigating to **File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question X'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut.  Markdown cells can be edited by double-clicking the cell to enter edit mode.
#
# The rubric contains _optional_ "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. If you decide to pursue the "Stand Out Suggestions", you should include the code in this Jupyter notebook.
#
#
#
# ---
# ### Why We're Here
#
# In this notebook, you will make the first steps towards developing an algorithm that could be used as part of a mobile or web app.  At the end of this project, your code will accept any user-supplied image as input.  If a dog is detected in the image, it will provide an estimate of the dog's breed.  If a human is detected, it will provide an estimate of the dog breed that is most resembling.  The image below displays potential sample output of your finished project (... but we expect that each student's algorithm will behave differently!).
#
# ![Sample Dog Output](images/sample_dog_output.png)
#
# In this real-world setting, you will need to piece together a series of models to perform different tasks; for instance, the algorithm that detects humans in an image will be different from the CNN that infers dog breed.  There are many points of possible failure, and no perfect algorithm exists.  Your imperfect solution will nonetheless create a fun user experience!
#
# ### The Road Ahead
#
# We break the notebook into separate steps.  Feel free to use the links below to navigate the notebook.
#
# * [Step 0](#step0): Import Datasets
# * [Step 1](#step1): Detect Humans
# * [Step 2](#step2): Detect Dogs
# * [Step 3](#step3): Create a CNN to Classify Dog Breeds (from Scratch)
# * [Step 4](#step4): Create a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 5](#step5): Write your Algorithm
# * [Step 6](#step6): Test Your Algorithm
#
# ---
# <a id='step0'></a>
# ## Step 0: Import Datasets
#
# Make sure that you've downloaded the required human and dog datasets:
# * Download the [dog dataset](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/dogImages.zip).  Unzip the folder and place it in this project's home directory, at the location `/dogImages`.
#
# * Download the [human dataset](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/lfw.zip).  Unzip the folder and place it in the home directory, at location `/lfw`.
#
# *Note: If you are using a Windows machine, you are encouraged to use [7zip](http://www.7-zip.org/) to extract the folder.*
#
# In the code cell below, we save the file paths for both the human (LFW) dataset and dog dataset in the numpy arrays `human_files` and `dog_files`.

# %%
import numpy as np
from glob import glob

# load filenames for human and dog images
human_files = np.array(glob("lfw/*/*"))
dog_files = np.array(glob("dogImages/*/*/*"))

# print number of images in each dataset
print('There are %d total human images.' % len(human_files))
print('There are %d total dog images.' % len(dog_files))
# Out:
# There are 13234 total human images.
# There are 8351 total dog images.

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Detect Humans
#
# In this section, we use OpenCV's implementation of [Haar feature-based cascade classifiers](http://docs.opencv.org/trunk/d7/d8b/tutorial_py_face_detection.html) to detect human faces in images.
#
# OpenCV provides many pre-trained face detectors, stored as XML files on [github](https://github.com/opencv/opencv/tree/master/data/haarcascades).  We have downloaded one of these detectors and stored it in the `haarcascades` directory.  In the next code cell, we demonstrate how to use this detector to find human faces in a sample image.

# %%
import cv2                
import matplotlib.pyplot as plt                        
# %matplotlib inline                               

# extract pre-trained face detector
face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')

# load color (BGR) image
img = cv2.imread(human_files[0])
# convert BGR image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# find faces in image
faces = face_cascade.detectMultiScale(gray)

# print number of faces detected in the image
print('Number of faces detected:', len(faces))

# get bounding box for each detected face
for (x,y,w,h) in faces:
    # add bounding box to color image
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    
# convert BGR image to RGB for plotting
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# display the image, along with bounding box
plt.imshow(cv_rgb)
plt.show()
# Out:
# Number of faces detected: 1

# %% [markdown]
# Before using any of the face detectors, it is standard procedure to convert the images to grayscale.  The `detectMultiScale` function executes the classifier stored in `face_cascade` and takes the grayscale image as a parameter.
#
# In the above code, `faces` is a numpy array of detected faces, where each row corresponds to a detected face.  Each detected face is a 1D array with four entries that specifies the bounding box of the detected face.  The first two entries in the array (extracted in the above code as `x` and `y`) specify the horizontal and vertical positions of the top left corner of the bounding box.  The last two entries in the array (extracted here as `w` and `h`) specify the width and height of the box.
#
# ### Write a Human Face Detector
#
# We can use this procedure to write a function that returns `True` if a human face is detected in an image and `False` otherwise.  This function, aptly named `face_detector`, takes a string-valued file path to an image as input and appears in the code block below.

# %%
# returns "True" if face is detected in image stored at img_path
def face_detector(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
    return len(faces) > 0

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Human Face Detector
#
# __Question 1:__ Use the code cell below to test the performance of the `face_detector` function.
# - What percentage of the first 100 images in `human_files` have a detected human face?
# - What percentage of the first 100 images in `dog_files` have a detected human face?
#
# Ideally, we would like 100% of human images with a detected face and 0% of dog images with a detected face.  You will see that our algorithm falls short of this goal, but still gives acceptable performance.  We extract the file paths for the first 100 images from each of the datasets and store them in the numpy arrays `human_files_short` and `dog_files_short`.

# %% [markdown]
# __Answer:__
# (You can print out your results and/or write your percentages in this cell)

# %%
from tqdm import tqdm

human_files_short = human_files[:100]
dog_files_short = dog_files[:100]

#-#-# Do NOT modify the code above this line. #-#-#

## TODO: Test the performance of the face_detector algorithm 
## on the images in human_files_short and dog_files_short.

face_detector_vectorized = np.vectorize(face_detector)

face_detected_in_human_files = np.round(face_detector_vectorized(human_files_short).mean() * 100)
face_detected_in_dog_files = np.round(face_detector_vectorized(dog_files_short).mean() * 100)

print('Detected faces in {}% of human files'.format(face_detected_in_human_files))
print('Detected faces in {}% dog files'.format(face_detected_in_dog_files))
# Out:
# Detected faces in 96.0% of human files
# Detected faces in 18.0% dog files

# %% [markdown]
# We suggest the face detector from OpenCV as a potential way to detect human images in your algorithm, but you are free to explore other approaches, especially approaches that make use of deep learning :).  Please use the code cell below to design and test your own face detection algorithm.  If you decide to pursue this _optional_ task, report performance on `human_files_short` and `dog_files_short`.

# %%
### (Optional) 
### TODO: Test performance of another face detection algorithm.
### Feel free to use as many code cells as needed.

# %% [markdown]
# ---
# <a id='step2'></a>
# ## Step 2: Detect Dogs
#
# In this section, we use a [pre-trained model](http://pytorch.org/docs/master/torchvision/models.html) to detect dogs in images.
#
# ### Obtain Pre-trained VGG-16 Model
#
# The code cell below downloads the VGG-16 model, along with weights that have been trained on [ImageNet](http://www.image-net.org/), a very large, very popular dataset used for image classification and other vision tasks.  ImageNet contains over 10 million URLs, each linking to an image containing an object from one of [1000 categories](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).

# %%
import torch
import torchvision.models as models

# define VGG16 model
VGG16 = models.vgg16(pretrained=True)

# check if CUDA is available
use_cuda = torch.cuda.is_available()

# move model to GPU if CUDA is available
if use_cuda:
    print('Cuda is available. Switching to CUDA')
    VGG16 = VGG16.cuda()
    
print(VGG16)
# Out:
# Cuda is available. Switching to CUDA
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace)
#     (2): Dropout(p=0.5)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace)
#     (5): Dropout(p=0.5)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %% [markdown]
# Given an image, this pre-trained VGG-16 model returns a prediction (derived from the 1000 possible categories in ImageNet) for the object that is contained in the image.

# %% [markdown]
# ### (IMPLEMENTATION) Making Predictions with a Pre-trained Model
#
# In the next code cell, you will write a function that accepts a path to an image (such as `'dogImages/train/001.Affenpinscher/Affenpinscher_00001.jpg'`) as input and returns the index corresponding to the ImageNet class that is predicted by the pre-trained VGG-16 model.  The output should always be an integer between 0 and 999, inclusive.
#
# Before writing the function, make sure that you take the time to learn  how to appropriately pre-process tensors for pre-trained models in the [PyTorch documentation](http://pytorch.org/docs/stable/torchvision/models.html).

# %%
from PIL import Image
import torchvision.transforms as transforms

# Set PIL to be tolerant of image files that are truncated.
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True


RESIZE_DIMS = (256, 256)


def VGG16_predict(img_path):
    '''
    Use pre-trained VGG-16 model to obtain index corresponding to 
    predicted ImageNet class for image at specified path
    
    Args:
        img_path: path to an image
        
    Returns:
        Index corresponding to VGG-16 model's prediction
    '''
    
    ## TODO: Complete the function.
    ## Load and pre-process an image from the given img_path
    ## Return the *index* of the predicted class for that image
    img_raw = Image.open(img_path)
    
    transformations = transforms.Compose([
        transforms.Resize(RESIZE_DIMS),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225])
    ])
    
    img = transformations(img_raw)
    img = img[None]
    
    if use_cuda:
        img = img.cuda()
    
    prediction = VGG16(img)
    
    prob, index = prediction[0, :].max(0)
    return int(index)

# %% [markdown]
# ### (IMPLEMENTATION) Write a Dog Detector
#
# While looking at the [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a), you will notice that the categories corresponding to dogs appear in an uninterrupted sequence and correspond to dictionary keys 151-268, inclusive, to include all categories from `'Chihuahua'` to `'Mexican hairless'`.  Thus, in order to check to see if an image is predicted to contain a dog by the pre-trained VGG-16 model, we need only check if the pre-trained model predicts an index between 151 and 268 (inclusive).
#
# Use these ideas to complete the `dog_detector` function below, which returns `True` if a dog is detected in an image (and `False` if not).

# %%
### returns "True" if a dog is detected in the image stored at img_path
def dog_detector(img_path):
    ## TODO: Complete the function.
    
    return (151 <= VGG16_predict(img_path) <= 268)  # true/false

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Dog Detector
#
# __Question 2:__ Use the code cell below to test the performance of your `dog_detector` function.
# - What percentage of the images in `human_files_short` have a detected dog?
# - What percentage of the images in `dog_files_short` have a detected dog?

# %% [markdown]
# __Answer:__

# %%
### TODO: Test the performance of the dog_detector function
### on the images in human_files_short and dog_files_short.
dog_detector_vectorized = np.vectorize(dog_detector)

dog_detected_in_human_files = np.round(dog_detector_vectorized(human_files_short).mean() * 100)
print('Detected dogs in {}% of human files'.format(dog_detected_in_human_files))
del dog_detected_in_human_files

dog_detected_in_dog_files = np.round(dog_detector_vectorized(dog_files_short).mean() * 100)
print('Detected dogs in {}% dog files'.format(dog_detected_in_dog_files))
del dog_detected_in_dog_files
# Out:
# Detected dogs in 0.0% of human files
# Detected dogs in 94.0% dog files

# %% [markdown]
# We suggest VGG-16 as a potential network to detect dog images in your algorithm, but you are free to explore other pre-trained networks (such as [Inception-v3](http://pytorch.org/docs/master/torchvision/models.html#inception-v3), [ResNet-50](http://pytorch.org/docs/master/torchvision/models.html#id3), etc).  Please use the code cell below to test other pre-trained PyTorch models.  If you decide to pursue this _optional_ task, report performance on `human_files_short` and `dog_files_short`.

# %%
### (Optional) 
### TODO: Report the performance of another pre-trained network.
### Feel free to use as many code cells as needed.

# %% [markdown]
# ---
# <a id='step3'></a>
# ## Step 3: Create a CNN to Classify Dog Breeds (from Scratch)
#
# Now that we have functions for detecting humans and dogs in images, we need a way to predict breed from images.  In this step, you will create a CNN that classifies dog breeds.  You must create your CNN _from scratch_ (so, you can't use transfer learning _yet_!), and you must attain a test accuracy of at least 10%.  In Step 4 of this notebook, you will have the opportunity to use transfer learning to create a CNN that attains greatly improved accuracy.
#
# We mention that the task of assigning breed to dogs from images is considered exceptionally challenging.  To see why, consider that *even a human* would have trouble distinguishing between a Brittany and a Welsh Springer Spaniel.
#
# Brittany | Welsh Springer Spaniel
# - | -
# <img src="images/Brittany_02625.jpg" width="100"> | <img src="images/Welsh_springer_spaniel_08203.jpg" width="200">
#
# It is not difficult to find other dog breed pairs with minimal inter-class variation (for instance, Curly-Coated Retrievers and American Water Spaniels).
#
# Curly-Coated Retriever | American Water Spaniel
# - | -
# <img src="images/Curly-coated_retriever_03896.jpg" width="200"> | <img src="images/American_water_spaniel_00648.jpg" width="200">
#
#
# Likewise, recall that labradors come in yellow, chocolate, and black.  Your vision-based algorithm will have to conquer this high intra-class variation to determine how to classify all of these different shades as the same breed.
#
# Yellow Labrador | Chocolate Labrador | Black Labrador
# - | -
# <img src="images/Labrador_retriever_06457.jpg" width="150"> | <img src="images/Labrador_retriever_06455.jpg" width="240"> | <img src="images/Labrador_retriever_06449.jpg" width="220">
#
# We also mention that random chance presents an exceptionally low bar: setting aside the fact that the classes are slightly imabalanced, a random guess will provide a correct answer roughly 1 in 133 times, which corresponds to an accuracy of less than 1%.
#
# Remember that the practice is far ahead of the theory in deep learning.  Experiment with many different architectures, and trust your intuition.  And, of course, have fun!
#
# ### (IMPLEMENTATION) Specify Data Loaders for the Dog Dataset
#
# Use the code cell below to write three separate [data loaders](http://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader) for the training, validation, and test datasets of dog images (located at `dogImages/train`, `dogImages/valid`, and `dogImages/test`, respectively).  You may find [this documentation on custom datasets](http://pytorch.org/docs/stable/torchvision/datasets.html) to be a useful resource.  If you are interested in augmenting your training and/or validation data, check out the wide variety of [transforms](http://pytorch.org/docs/stable/torchvision/transforms.html?highlight=transform)!

# %%
import os
from torchvision import datasets

### TODO: Write data loaders for training, validation, and test sets
## Specify appropriate transforms, and batch_sizes


loaders_scratch = {}
BATCH_SIZE = 4

# Train set
train_transforms = transforms.Compose([
    transforms.Resize(RESIZE_DIMS),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(20),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])
train_folder = datasets.ImageFolder('dogImages/train/', transform=train_transforms)
loaders_scratch['train'] = torch.utils.data.DataLoader(train_folder,
                                           batch_size=BATCH_SIZE,
                                           shuffle=True)

# Validation set
valid_transforms = transforms.Compose([
    transforms.Resize(RESIZE_DIMS),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])
valid_folder = datasets.ImageFolder('dogImages/valid/', transform=valid_transforms)
loaders_scratch['valid'] = torch.utils.data.DataLoader(valid_folder,
                                                       batch_size=BATCH_SIZE,
                                                       shuffle=False)

# Test set
test_transforms = transforms.Compose([
    transforms.Resize(RESIZE_DIMS),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])
test_folder = datasets.ImageFolder('dogImages/test/', transform=test_transforms)
loaders_scratch['test'] = torch.utils.data.DataLoader(test_folder,
                                           batch_size=BATCH_SIZE,
                                           shuffle=False)

# %% [markdown]
# **Question 3:** Describe your chosen procedure for preprocessing the data.
# - How does your code resize the images (by cropping, stretching, etc)?  What size did you pick for the input tensor, and why?
# - Did you decide to augment the dataset?  If so, how (through translations, flips, rotations, etc)?  If not, why not?

# %% [markdown]
# **Answer**:
#
# - I resize images to the same size accross the whole project using the constant `RESIZE_DIMS = (256, 256)`. This size is compatible with VGG16 and also is a power of two, which makes easier to compute output sizes. This size is achieved by stretching the image. I prefer this way because it minimizes the possibility of loosing some important information
# - I'm augmenting the dataset by flipping it horizontally and by rotating it randomly by at most 20 degrees. This should be enough to mimic the behavior of pictures take by humans.

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  Use the template in the code cell below.

# %%
import torch.nn as nn
import torch.nn.functional as F

# define the CNN architecture
class Net(nn.Module):
    ### TODO: choose an architecture, and complete the class
    def __init__(self):
        super(Net, self).__init__()
        
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=64, kernel_size=(3, 3), stride=1, padding=1)
        self.conv2 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=(3, 3), stride=1, padding=1)
        self.conv2_bn = nn.BatchNorm2d(64)
        self.conv3 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=(3, 3), stride=1, padding=1)
        self.conv3_bn = nn.BatchNorm2d(128)
        self.conv4 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=(3, 3), stride=1, padding=1)
        self.conv4_bn = nn.BatchNorm2d(256)
        self.conv5 = nn.Conv2d(in_channels=256, out_channels=512, kernel_size=(3, 3), stride=1, padding=1)
        self.conv5_bn = nn.BatchNorm2d(512)
        
        self.fc1 = nn.Linear(4 * 4 * 512, 4096)
        self.fc1_bn = nn.BatchNorm1d(4096)
        self.fc2 = nn.Linear(4096, 4096)
        self.fc2_bn = nn.BatchNorm1d(4096)
        self.fc3 = nn.Linear(4096, 133)
        
        self.pool = nn.MaxPool2d(kernel_size=(2, 2), stride=2)
        self.pool4 = nn.MaxPool2d(kernel_size=(4, 4), stride=4)
        self.drop = nn.Dropout(0.5)
        
    
    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.pool4(x)
        
        x = self.conv2(x)
        x = self.conv2_bn(x)
        x = F.relu(x)
        x = self.pool(x)
        
        x = self.conv3(x)
        x = self.conv3_bn(x)
        x = F.relu(x)
        x = self.pool(x)
        
        x = self.conv4(x)
        x = self.conv4_bn(x)
        x = F.relu(x)
        x = self.pool(x)
        
        x = self.conv5(x)
        x = self.conv5_bn(x)
        x = F.relu(x)
        x = self.pool(x)
        
        x = x.view(-1, 4 * 4 * 512)
        x = self.drop(x)
        
        x = self.fc1(x)
        x = F.relu(x)
        x = self.drop(x)
        
        x = self.fc2(x)
        x = F.relu(x)
        x = self.drop(x)
        
        return x

#-#-# You do NOT have to modify the code below this line. #-#-#

# instantiate the CNN
model_scratch = Net()

# move tensors to GPU if CUDA is available
if use_cuda:
    model_scratch.cuda()

# %% [markdown]
# __Question 4:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.

# %% [markdown]
# __Answer:__
#
# I took a peek into the VGG16 architecture to get some ideas, as this architecture has been succesfully applied to other computer vision problems.
#
# **Features layers**
#
# I'm using convolution layers to extract _features_ or patterns from the images, starting with 64 _filters_ in the first layer, and going to up to 512. The first two layers are connected directly and then comes a max pooling layer. All other convolutional layers are followed by a maxpooling layer, so each one is _narrower_ and _deeper_. All of the layers use a ReLU activation function.
#
# **CLassification layers**
#
# Finally, the ouput of the last convolutional layer is flatten and then passed to two consecutive fully connected layers with 4096 neurons. These layers have a 25% dropout and use a ReLU activation function.
#
# I'm also using batch normalization to improve learning speed, as this kind of layers allow for other layers apart from the input to be normalized.

# %% [markdown]
# ### (IMPLEMENTATION) Specify Loss Function and Optimizer
#
# Use the next code cell to specify a [loss function](http://pytorch.org/docs/stable/nn.html#loss-functions) and [optimizer](http://pytorch.org/docs/stable/optim.html).  Save the chosen loss function as `criterion_scratch`, and the optimizer as `optimizer_scratch` below.

# %%
import torch.optim as optim

### TODO: select loss function
criterion_scratch = nn.CrossEntropyLoss()

### TODO: select optimizer
optimizer_scratch = optim.SGD(model_scratch.parameters(), lr=0.001)
scheduler_scratch = optim.lr_scheduler.ReduceLROnPlateau(optimizer_scratch)

# %% [markdown]
# ### (IMPLEMENTATION) Train and Validate the Model
#
# Train and validate your model in the code cell below.  [Save the final model parameters](http://pytorch.org/docs/master/notes/serialization.html) at filepath `'model_scratch.pt'`.

# %%
# the following import is required for training to be robust to truncated images
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

N_EPOCHS = 100
STEPS_PER_EPOCH = 133 * 10

data = torch.empty((BATCH_SIZE, 3) + RESIZE_DIMS)
target = torch.empty((133, ))
output = torch.empty((133, ))
loss = torch.empty((1, ))

def train(n_epochs, loaders, model, optimizer, criterion, use_cuda, save_path, scheduler=None):
    """returns trained model"""
    print('Training model...')
    # initialize tracker for minimum validation loss
    valid_loss_min = np.Inf 
    
    for epoch in range(1, n_epochs+1):
        memory_allocated = torch.cuda.memory_allocated()
        print('Starting epoch {}/{}. Memory allocated: {}'.format(
            epoch,
            n_epochs,
            memory_allocated
        ))
        
        # initialize variables to monitor training and validation loss
        train_loss = 0.0
        valid_loss = 0.0
        
        ###################
        # train the model #
        ###################
        model.train()
        batch_idx = 1
        for data, target in loaders['train']:
            # move to GPU
            if use_cuda:
                data, target = data.cuda(), target.cuda()
            ## find the loss and update the model parameters accordingly
            ## record the average training loss, using something like
            ## train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
            
            optimizer.zero_grad()
            output = model(data)
            
            loss = criterion(output, target)

            loss.backward()
            
            optimizer.step()
            
            train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
            
            if batch_idx >= STEPS_PER_EPOCH:
                break
                
            batch_idx += 1
            
            
        ######################    
        # validate the model #
        ######################
        model.eval()
        batch_idx = 1
        for data, target in loaders['valid']:
                
            # move to GPU
            if use_cuda:
                data, target = data.cuda(), target.cuda()
            
            ## update the average validation loss
            output = model(data)
            # calculate the batch loss
            loss = criterion(output, target)
            
            # update average validation loss 
            valid_loss = valid_loss + ((1 / (batch_idx + 1)) * (loss.data - valid_loss))

            batch_idx += 1
        
        if scheduler:
            scheduler.step(valid_loss)
        
        # print training/validation statistics 
        memory_allocated = torch.cuda.memory_allocated()
        print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f} \tMemory allocated: {}'.format(
            epoch, 
            train_loss,
            valid_loss,
            memory_allocated
            ))
        
        ## TODO: save the model if validation loss has decreased
        if valid_loss <= valid_loss_min:
            print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
            valid_loss_min,
            valid_loss))
            torch.save(model.state_dict(), save_path)
            valid_loss_min = valid_loss
            
    # return trained model
    return model


# train the model
model_scratch = train(N_EPOCHS, loaders_scratch, model_scratch, optimizer_scratch, 
                      criterion_scratch, use_cuda, 'model_scratch.pt', scheduler_scratch)

# load the model that got the best validation accuracy
model_scratch.load_state_dict(torch.load('model_scratch.pt'))
# Out:
# Training model...
# Starting epoch 1/100. Memory allocated: 764912128
# Epoch: 1 	Training Loss: 7.476829 	Validation Loss: 6.679949 	Memory allocated: 1112963584
# Validation loss decreased (inf --> 6.679949).  Saving model ...
# Starting epoch 2/100. Memory allocated: 1112963584
# Epoch: 2 	Training Loss: 7.087258 	Validation Loss: 6.535217 	Memory allocated: 1112964096
# Validation loss decreased (6.679949 --> 6.535217).  Saving model ...
# Starting epoch 3/100. Memory allocated: 1112963584
# Epoch: 3 	Training Loss: 6.995866 	Validation Loss: 6.601605 	Memory allocated: 1112964096
# Starting epoch 4/100. Memory allocated: 1112964096
# Epoch: 4 	Training Loss: 6.839085 	Validation Loss: 6.316558 	Memory allocated: 1112964096
# Validation loss decreased (6.535217 --> 6.316558).  Saving model ...
# Starting epoch 5/100. Memory allocated: 1112963584
# Epoch: 5 	Training Loss: 6.749323 	Validation Loss: 6.299227 	Memory allocated: 1112964096
# Validation loss decreased (6.316558 --> 6.299227).  Saving model ...
# Starting epoch 6/100. Memory allocated: 1112963584
# Epoch: 6 	Training Loss: 6.742863 	Validation Loss: 6.349010 	Memory allocated: 1112964096
# Starting epoch 7/100. Memory allocated: 1112964096
# Epoch: 7 	Training Loss: 6.728308 	Validation Loss: 6.270161 	Memory allocated: 1112964096
# Validation loss decreased (6.299227 --> 6.270161).  Saving model ...
# Starting epoch 8/100. Memory allocated: 1112963584
# Epoch: 8 	Training Loss: 6.650954 	Validation Loss: 6.125601 	Memory allocated: 1112964096
# Validation loss decreased (6.270161 --> 6.125601).  Saving model ...
# Starting epoch 9/100. Memory allocated: 1112963584
# Epoch: 9 	Training Loss: 6.622262 	Validation Loss: 6.249131 	Memory allocated: 1112964096
# Starting epoch 10/100. Memory allocated: 1112964096
# Epoch: 10 	Training Loss: 6.607104 	Validation Loss: 6.180874 	Memory allocated: 1112964096
# Starting epoch 11/100. Memory allocated: 1112964096
# Epoch: 11 	Training Loss: 6.655703 	Validation Loss: 6.191046 	Memory allocated: 1112964096
# Starting epoch 12/100. Memory allocated: 1112964096
# Epoch: 12 	Training Loss: 6.531607 	Validation Loss: 6.228368 	Memory allocated: 1112964096
# Starting epoch 13/100. Memory allocated: 1112964096
# Epoch: 13 	Training Loss: 6.604285 	Validation Loss: 6.193963 	Memory allocated: 1112964096
# Starting epoch 14/100. Memory allocated: 1112964096
# Epoch: 14 	Training Loss: 6.598136 	Validation Loss: 5.971905 	Memory allocated: 1112964096
# Validation loss decreased (6.125601 --> 5.971905).  Saving model ...
# Starting epoch 15/100. Memory allocated: 1112963584
# Epoch: 15 	Training Loss: 6.595170 	Validation Loss: 6.106324 	Memory allocated: 1112964096
# Starting epoch 16/100. Memory allocated: 1112964096
# Epoch: 16 	Training Loss: 6.468213 	Validation Loss: 6.088983 	Memory allocated: 1112964096
# Starting epoch 17/100. Memory allocated: 1112964096
# Epoch: 17 	Training Loss: 6.518680 	Validation Loss: 5.971714 	Memory allocated: 1112964096
# Validation loss decreased (5.971905 --> 5.971714).  Saving model ...
# Starting epoch 18/100. Memory allocated: 1112964096
# Epoch: 18 	Training Loss: 6.477111 	Validation Loss: 5.983658 	Memory allocated: 1112964608
# Starting epoch 19/100. Memory allocated: 1112964608
# Epoch: 19 	Training Loss: 6.488401 	Validation Loss: 5.902286 	Memory allocated: 1112964096
# Validation loss decreased (5.971714 --> 5.902286).  Saving model ...
# Starting epoch 20/100. Memory allocated: 1112963584
# Epoch: 20 	Training Loss: 6.416782 	Validation Loss: 5.837228 	Memory allocated: 1112964096
# Validation loss decreased (5.902286 --> 5.837228).  Saving model ...
# Starting epoch 21/100. Memory allocated: 1112963584
# Epoch: 21 	Training Loss: 6.457897 	Validation Loss: 5.978755 	Memory allocated: 1112964096
# Starting epoch 22/100. Memory allocated: 1112964096
# Epoch: 22 	Training Loss: 6.411434 	Validation Loss: 5.900629 	Memory allocated: 1112964096
# Starting epoch 23/100. Memory allocated: 1112964096
# Epoch: 23 	Training Loss: 6.331011 	Validation Loss: 5.930591 	Memory allocated: 1112964096
# Starting epoch 24/100. Memory allocated: 1112964096
# Epoch: 24 	Training Loss: 6.437434 	Validation Loss: 5.916112 	Memory allocated: 1112964096
# Starting epoch 25/100. Memory allocated: 1112964096
# Epoch: 25 	Training Loss: 6.382647 	Validation Loss: 5.838048 	Memory allocated: 1112964096
# Starting epoch 26/100. Memory allocated: 1112964096
# Epoch: 26 	Training Loss: 6.378127 	Validation Loss: 5.908991 	Memory allocated: 1112964096
# Starting epoch 27/100. Memory allocated: 1112964096
# Epoch: 27 	Training Loss: 6.316123 	Validation Loss: 5.870207 	Memory allocated: 1112964096
# Starting epoch 28/100. Memory allocated: 1112964096
# Epoch: 28 	Training Loss: 6.262582 	Validation Loss: 5.918666 	Memory allocated: 1112964096
# Starting epoch 29/100. Memory allocated: 1112964096
# Epoch: 29 	Training Loss: 6.378946 	Validation Loss: 5.933960 	Memory allocated: 1112964096
# Starting epoch 30/100. Memory allocated: 1112964096
# Epoch: 30 	Training Loss: 6.337284 	Validation Loss: 5.882198 	Memory allocated: 1112964096
# Starting epoch 31/100. Memory allocated: 1112964096
# Epoch: 31 	Training Loss: 6.325088 	Validation Loss: 5.898449 	Memory allocated: 1112964096
# Starting epoch 32/100. Memory allocated: 1112964096
# Epoch: 32 	Training Loss: 6.242710 	Validation Loss: 5.805398 	Memory allocated: 1112964096
# Validation loss decreased (5.837228 --> 5.805398).  Saving model ...
# Starting epoch 33/100. Memory allocated: 1112963584
# Epoch: 33 	Training Loss: 6.203646 	Validation Loss: 5.785618 	Memory allocated: 1112964096
# Validation loss decreased (5.805398 --> 5.785618).  Saving model ...
# Starting epoch 34/100. Memory allocated: 1112963584
# Epoch: 34 	Training Loss: 6.235898 	Validation Loss: 5.743443 	Memory allocated: 1112964096
# Validation loss decreased (5.785618 --> 5.743443).  Saving model ...
# Starting epoch 35/100. Memory allocated: 1112963584
# Epoch: 35 	Training Loss: 6.260787 	Validation Loss: 5.799415 	Memory allocated: 1112964096
# Starting epoch 36/100. Memory allocated: 1112964096
# Epoch: 36 	Training Loss: 6.219882 	Validation Loss: 5.772952 	Memory allocated: 1112964096
# Starting epoch 37/100. Memory allocated: 1112964096
# Epoch: 37 	Training Loss: 6.141812 	Validation Loss: 5.770764 	Memory allocated: 1112964096
# Starting epoch 38/100. Memory allocated: 1112964096
# Epoch: 38 	Training Loss: 6.217988 	Validation Loss: 5.779074 	Memory allocated: 1112964096
# Starting epoch 39/100. Memory allocated: 1112964096
# Epoch: 39 	Training Loss: 6.217158 	Validation Loss: 5.775113 	Memory allocated: 1112964096
# Starting epoch 40/100. Memory allocated: 1112964096
# Epoch: 40 	Training Loss: 6.145406 	Validation Loss: 5.751781 	Memory allocated: 1112964096
# Starting epoch 41/100. Memory allocated: 1112964096
# Epoch: 41 	Training Loss: 6.219499 	Validation Loss: 5.750042 	Memory allocated: 1112964096
# Starting epoch 42/100. Memory allocated: 1112964096
# Epoch: 42 	Training Loss: 6.292952 	Validation Loss: 5.799407 	Memory allocated: 1112964096
# Starting epoch 43/100. Memory allocated: 1112964096
# Epoch: 43 	Training Loss: 6.214363 	Validation Loss: 5.815377 	Memory allocated: 1112964096
# Starting epoch 44/100. Memory allocated: 1112964096
# Epoch: 44 	Training Loss: 6.222136 	Validation Loss: 5.789884 	Memory allocated: 1112964096
# Starting epoch 45/100. Memory allocated: 1112964096
# Epoch: 45 	Training Loss: 6.231634 	Validation Loss: 5.759645 	Memory allocated: 1112964096
# Starting epoch 46/100. Memory allocated: 1112964096
# Epoch: 46 	Training Loss: 6.177045 	Validation Loss: 5.753876 	Memory allocated: 1112964096
# Starting epoch 47/100. Memory allocated: 1112964096
# Epoch: 47 	Training Loss: 6.170303 	Validation Loss: 5.757726 	Memory allocated: 1112964096
# Starting epoch 48/100. Memory allocated: 1112964096
# Epoch: 48 	Training Loss: 6.131950 	Validation Loss: 5.784006 	Memory allocated: 1112964096
# Starting epoch 49/100. Memory allocated: 1112964096
# Epoch: 49 	Training Loss: 6.196267 	Validation Loss: 5.759694 	Memory allocated: 1112964096
# Starting epoch 50/100. Memory allocated: 1112964096
# Epoch: 50 	Training Loss: 6.180047 	Validation Loss: 5.755767 	Memory allocated: 1112964096
# Starting epoch 51/100. Memory allocated: 1112964096
# Epoch: 51 	Training Loss: 6.146177 	Validation Loss: 5.747583 	Memory allocated: 1112964096
# Starting epoch 52/100. Memory allocated: 1112964096
# Epoch: 52 	Training Loss: 6.203036 	Validation Loss: 5.756146 	Memory allocated: 1112964096
# Starting epoch 53/100. Memory allocated: 1112964096
# Epoch: 53 	Training Loss: 6.132744 	Validation Loss: 5.742849 	Memory allocated: 1112964096
# Validation loss decreased (5.743443 --> 5.742849).  Saving model ...
# Starting epoch 54/100. Memory allocated: 1112963584
# Epoch: 54 	Training Loss: 6.205593 	Validation Loss: 5.747028 	Memory allocated: 1112964096
# Starting epoch 55/100. Memory allocated: 1112964096
# Epoch: 55 	Training Loss: 6.139087 	Validation Loss: 5.762786 	Memory allocated: 1112964096
# Starting epoch 56/100. Memory allocated: 1112964096
# Epoch: 56 	Training Loss: 6.196013 	Validation Loss: 5.735379 	Memory allocated: 1112964096
# Validation loss decreased (5.742849 --> 5.735379).  Saving model ...
# Starting epoch 57/100. Memory allocated: 1112963584
# Epoch: 57 	Training Loss: 6.177864 	Validation Loss: 5.752244 	Memory allocated: 1112964096
# Starting epoch 58/100. Memory allocated: 1112964096
# Epoch: 58 	Training Loss: 6.162290 	Validation Loss: 5.746068 	Memory allocated: 1112964096
# Starting epoch 59/100. Memory allocated: 1112964096
# Epoch: 59 	Training Loss: 6.152353 	Validation Loss: 5.735569 	Memory allocated: 1112964096
# Starting epoch 60/100. Memory allocated: 1112964096
# Epoch: 60 	Training Loss: 6.171896 	Validation Loss: 5.733000 	Memory allocated: 1112964096
# Validation loss decreased (5.735379 --> 5.733000).  Saving model ...
# Starting epoch 61/100. Memory allocated: 1112963584
# Epoch: 61 	Training Loss: 6.208299 	Validation Loss: 5.762473 	Memory allocated: 1112964096
# Starting epoch 62/100. Memory allocated: 1112964096
# Epoch: 62 	Training Loss: 6.172837 	Validation Loss: 5.740208 	Memory allocated: 1112964096
# Starting epoch 63/100. Memory allocated: 1112964096
# Epoch: 63 	Training Loss: 6.189092 	Validation Loss: 5.756546 	Memory allocated: 1112964096
# Starting epoch 64/100. Memory allocated: 1112964096
# Epoch: 64 	Training Loss: 6.098436 	Validation Loss: 5.747834 	Memory allocated: 1112964096
# Starting epoch 65/100. Memory allocated: 1112964096
# Epoch: 65 	Training Loss: 6.160622 	Validation Loss: 5.718835 	Memory allocated: 1112964096
# Validation loss decreased (5.733000 --> 5.718835).  Saving model ...
# Starting epoch 66/100. Memory allocated: 1112963584
# Epoch: 66 	Training Loss: 6.155292 	Validation Loss: 5.739959 	Memory allocated: 1112964096
# Starting epoch 67/100. Memory allocated: 1112964096
# Epoch: 67 	Training Loss: 6.081226 	Validation Loss: 5.732744 	Memory allocated: 1112964096
# Starting epoch 68/100. Memory allocated: 1112964096
# Epoch: 68 	Training Loss: 6.171675 	Validation Loss: 5.740836 	Memory allocated: 1112964096
# Starting epoch 69/100. Memory allocated: 1112964096
# Epoch: 69 	Training Loss: 6.107048 	Validation Loss: 5.744503 	Memory allocated: 1112964096
# Starting epoch 70/100. Memory allocated: 1112964096
# Epoch: 70 	Training Loss: 6.086949 	Validation Loss: 5.718961 	Memory allocated: 1112964096
# Starting epoch 71/100. Memory allocated: 1112964096
# Epoch: 71 	Training Loss: 6.148618 	Validation Loss: 5.717362 	Memory allocated: 1112964096
# Validation loss decreased (5.718835 --> 5.717362).  Saving model ...
# Starting epoch 72/100. Memory allocated: 1112963584
# Epoch: 72 	Training Loss: 6.121156 	Validation Loss: 5.722687 	Memory allocated: 1112964096
# Starting epoch 73/100. Memory allocated: 1112964096
# Epoch: 73 	Training Loss: 6.227039 	Validation Loss: 5.738696 	Memory allocated: 1112964096
# Starting epoch 74/100. Memory allocated: 1112964096
# Epoch: 74 	Training Loss: 6.123454 	Validation Loss: 5.698524 	Memory allocated: 1112964096
# Validation loss decreased (5.717362 --> 5.698524).  Saving model ...
# Starting epoch 75/100. Memory allocated: 1112963584
# Epoch: 75 	Training Loss: 6.189279 	Validation Loss: 5.744917 	Memory allocated: 1112964096
# Starting epoch 76/100. Memory allocated: 1112964096
# Epoch: 76 	Training Loss: 6.184293 	Validation Loss: 5.726753 	Memory allocated: 1112964096
# Starting epoch 77/100. Memory allocated: 1112964096
# Epoch: 77 	Training Loss: 6.111364 	Validation Loss: 5.746272 	Memory allocated: 1112964096
# Starting epoch 78/100. Memory allocated: 1112964096
# Epoch: 78 	Training Loss: 6.133952 	Validation Loss: 5.709568 	Memory allocated: 1112964096
# Starting epoch 79/100. Memory allocated: 1112964096
# Epoch: 79 	Training Loss: 6.113267 	Validation Loss: 5.739460 	Memory allocated: 1112964096
# Starting epoch 80/100. Memory allocated: 1112964096
# Epoch: 80 	Training Loss: 6.115392 	Validation Loss: 5.722645 	Memory allocated: 1112964096
# Starting epoch 81/100. Memory allocated: 1112964096
# Epoch: 81 	Training Loss: 6.200732 	Validation Loss: 5.758786 	Memory allocated: 1112964096
# Starting epoch 82/100. Memory allocated: 1112964096
# Epoch: 82 	Training Loss: 6.221680 	Validation Loss: 5.736264 	Memory allocated: 1112964096
# Starting epoch 83/100. Memory allocated: 1112964096
# Epoch: 83 	Training Loss: 6.134966 	Validation Loss: 5.752301 	Memory allocated: 1112964096
# Starting epoch 84/100. Memory allocated: 1112964096
# Epoch: 84 	Training Loss: 6.141384 	Validation Loss: 5.739451 	Memory allocated: 1112964096
# Starting epoch 85/100. Memory allocated: 1112964096
# Epoch: 85 	Training Loss: 6.096355 	Validation Loss: 5.717475 	Memory allocated: 1112964096
# Starting epoch 86/100. Memory allocated: 1112964096
# Epoch: 86 	Training Loss: 6.156619 	Validation Loss: 5.728332 	Memory allocated: 1112964096
# Starting epoch 87/100. Memory allocated: 1112964096
# Epoch: 87 	Training Loss: 6.158028 	Validation Loss: 5.745021 	Memory allocated: 1112964096
# Starting epoch 88/100. Memory allocated: 1112964096
# Epoch: 88 	Training Loss: 6.193925 	Validation Loss: 5.752128 	Memory allocated: 1112964096
# Starting epoch 89/100. Memory allocated: 1112964096
# Epoch: 89 	Training Loss: 6.131366 	Validation Loss: 5.713843 	Memory allocated: 1112964096
# Starting epoch 90/100. Memory allocated: 1112964096
# Epoch: 90 	Training Loss: 6.045484 	Validation Loss: 5.730810 	Memory allocated: 1112964096
# Starting epoch 91/100. Memory allocated: 1112964096
# Epoch: 91 	Training Loss: 6.057290 	Validation Loss: 5.756823 	Memory allocated: 1112964096
# Starting epoch 92/100. Memory allocated: 1112964096
# Epoch: 92 	Training Loss: 6.108481 	Validation Loss: 5.732177 	Memory allocated: 1112964096
# Starting epoch 93/100. Memory allocated: 1112964096
# Epoch: 93 	Training Loss: 6.174975 	Validation Loss: 5.716422 	Memory allocated: 1112964096
# Starting epoch 94/100. Memory allocated: 1112964096
# Epoch: 94 	Training Loss: 6.160510 	Validation Loss: 5.732360 	Memory allocated: 1112964096
# Starting epoch 95/100. Memory allocated: 1112964096
# Epoch: 95 	Training Loss: 6.083529 	Validation Loss: 5.746392 	Memory allocated: 1112964096
# Starting epoch 96/100. Memory allocated: 1112964096
# Epoch: 96 	Training Loss: 6.153858 	Validation Loss: 5.732194 	Memory allocated: 1112964096
# Starting epoch 97/100. Memory allocated: 1112964096
# Epoch: 97 	Training Loss: 6.199603 	Validation Loss: 5.735236 	Memory allocated: 1112964096
# Starting epoch 98/100. Memory allocated: 1112964096
# Epoch: 98 	Training Loss: 6.091259 	Validation Loss: 5.720029 	Memory allocated: 1112964096
# Starting epoch 99/100. Memory allocated: 1112964096
# Epoch: 99 	Training Loss: 6.133057 	Validation Loss: 5.736460 	Memory allocated: 1112964096
# Starting epoch 100/100. Memory allocated: 1112964096
# Epoch: 100 	Training Loss: 6.110959 	Validation Loss: 5.727213 	Memory allocated: 1112964096

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images.  Use the code cell below to calculate and print the test loss and accuracy.  Ensure that your test accuracy is greater than 10%.

# %%
data = torch.empty((BATCH_SIZE, 3) + RESIZE_DIMS)
target = torch.empty((133, ))
output = torch.empty((133, ))


def test(loaders, model, criterion, use_cuda):

    # monitor test loss and accuracy
    test_loss = 0.
    correct = 0.
    total = 0.

    model.eval()
    batch_idx = 1
    for data, target in loaders['test']:
        # move to GPU
        if use_cuda:
            data, target = data.cuda(), target.cuda()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        # update average test loss 
        test_loss = test_loss + ((1 / (batch_idx + 1)) * (loss.data - test_loss))
        # convert output probabilities to predicted class
        pred = output.data.max(1, keepdim=True)[1]
        # compare predictions to true label
        correct += np.sum(np.squeeze(pred.eq(target.data.view_as(pred))).cpu().numpy())
        total += data.size(0)
        batch_idx += 1
            
    print('Test Loss: {:.6f}\n'.format(test_loss))

    print('\nTest Accuracy: %2d%% (%2d/%2d)' % (
        100. * correct / total, correct, total))

# call test function    
test(loaders_scratch, model_scratch, criterion_scratch, use_cuda)
# Out:
# Test Loss: 5.690932
#
#
# Test Accuracy: 18% (157/836)

# %% [markdown]
# ---
# <a id='step4'></a>
# ## Step 4: Create a CNN to Classify Dog Breeds (using Transfer Learning)
#
# You will now use transfer learning to create a CNN that can identify dog breed from images.  Your CNN must attain at least 60% accuracy on the test set.
#
# ### (IMPLEMENTATION) Specify Data Loaders for the Dog Dataset
#
# Use the code cell below to write three separate [data loaders](http://pytorch.org/docs/master/data.html#torch.utils.data.DataLoader) for the training, validation, and test datasets of dog images (located at `dogImages/train`, `dogImages/valid`, and `dogImages/test`, respectively).
#
# If you like, **you are welcome to use the same data loaders from the previous step**, when you created a CNN from scratch.

# %%
## TODO: Specify data loaders
loaders_transfer = loaders_scratch

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Use transfer learning to create a CNN to classify dog breed.  Use the code cell below, and save your initialized model as the variable `model_transfer`.

# %%
import torchvision.models as models
import torch.nn as nn

## TODO: Specify model architecture 
model_transfer = VGG16

# Freeze features parameters
for param in model_transfer.features.parameters():
    param.requires_grad = False
    
n_inputs = model_transfer.classifier[6].in_features

last_layer = nn.Linear(n_inputs, 133)
model_transfer.classifier[6] = last_layer

if use_cuda:
    model_transfer = model_transfer.cuda()
    
print(model_transfer)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace)
#     (2): Dropout(p=0.5)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace)
#     (5): Dropout(p=0.5)
#     (6): Linear(in_features=4096, out_features=133, bias=True)
#   )
# )

# %% [markdown]
# __Question 5:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  Describe why you think the architecture is suitable for the current problem.

# %% [markdown]
# __Answer:__
#
# I'm using the _features_ layers from `VGG16` as they come, without training them, because it's already capable of recognizing a lot of dog breeds, so there must be relevant features for the dog breed classifier I'm trying to train here. I'm keeping the first two of the `classifier` linear layers, their activations and their dropouts. Finally, I'm modifying the last layer so it outputs 133 probabilities to match the number of classes in this problem.

# %% [markdown]
# ### (IMPLEMENTATION) Specify Loss Function and Optimizer
#
# Use the next code cell to specify a [loss function](http://pytorch.org/docs/master/nn.html#loss-functions) and [optimizer](http://pytorch.org/docs/master/optim.html).  Save the chosen loss function as `criterion_transfer`, and the optimizer as `optimizer_transfer` below.

# %%
criterion_transfer = nn.CrossEntropyLoss()
optimizer_transfer = optim.SGD(model_transfer.parameters(), lr=0.001)
scheduler_transfer = optim.lr_scheduler.ReduceLROnPlateau(optimizer_transfer)

# %% [markdown]
# ### (IMPLEMENTATION) Train and Validate the Model
#
# Train and validate your model in the code cell below.  [Save the final model parameters](http://pytorch.org/docs/master/notes/serialization.html) at filepath `'model_transfer.pt'`.

# %%
# train the model
N_EPOCHS_TRANSFER = 10
model_transfer = train(N_EPOCHS_TRANSFER, loaders_transfer, model_transfer, optimizer_transfer, criterion_transfer, use_cuda, 'model_transfer.pt', scheduler_transfer)
# Out:
# Training model...
# Starting epoch 1/10. Memory allocated: 1169351680
# Epoch: 1 	Training Loss: 2.377126 	Validation Loss: 0.813870 	Memory allocated: 1652529664
# Validation loss decreased (inf --> 0.813870).  Saving model ...
# Starting epoch 2/10. Memory allocated: 1652529664
# Epoch: 2 	Training Loss: 0.936040 	Validation Loss: 0.585274 	Memory allocated: 1652530176
# Validation loss decreased (0.813870 --> 0.585274).  Saving model ...
# Starting epoch 3/10. Memory allocated: 1652529664
# Epoch: 3 	Training Loss: 0.748118 	Validation Loss: 0.521578 	Memory allocated: 1652530176
# Validation loss decreased (0.585274 --> 0.521578).  Saving model ...
# Starting epoch 4/10. Memory allocated: 1652529664
# Epoch: 4 	Training Loss: 0.637085 	Validation Loss: 0.482352 	Memory allocated: 1652530176
# Validation loss decreased (0.521578 --> 0.482352).  Saving model ...
# Starting epoch 5/10. Memory allocated: 1652529664
# Epoch: 5 	Training Loss: 0.561536 	Validation Loss: 0.544558 	Memory allocated: 1652530176
# Starting epoch 6/10. Memory allocated: 1652530176
# Epoch: 6 	Training Loss: 0.528294 	Validation Loss: 0.448126 	Memory allocated: 1652530176
# Validation loss decreased (0.482352 --> 0.448126).  Saving model ...
# Starting epoch 7/10. Memory allocated: 1652529664
# Epoch: 7 	Training Loss: 0.466591 	Validation Loss: 0.459183 	Memory allocated: 1652530176
# Starting epoch 8/10. Memory allocated: 1652530176
# Epoch: 8 	Training Loss: 0.444420 	Validation Loss: 0.455752 	Memory allocated: 1652530176
# Starting epoch 9/10. Memory allocated: 1652530176
# Epoch: 9 	Training Loss: 0.403330 	Validation Loss: 0.439602 	Memory allocated: 1652530176
# Validation loss decreased (0.448126 --> 0.439602).  Saving model ...
# Starting epoch 10/10. Memory allocated: 1652529664
# Epoch: 10 	Training Loss: 0.361710 	Validation Loss: 0.429621 	Memory allocated: 1652530176
# Validation loss decreased (0.439602 --> 0.429621).  Saving model ...

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images. Use the code cell below to calculate and print the test loss and accuracy.  Ensure that your test accuracy is greater than 60%.

# %%
model_transfer.load_state_dict(torch.load('model_transfer.pt'))

data = torch.empty((BATCH_SIZE, 3) + RESIZE_DIMS)
target = torch.empty((133, ))
output = torch.empty((133, ))
loss = torch.empty((1, ))

test(loaders_transfer, model_transfer, criterion_transfer, use_cuda)
# Out:
# Test Loss: 0.495784
#
#
# Test Accuracy: 85% (713/836)

# %% [markdown]
# ### (IMPLEMENTATION) Predict Dog Breed with the Model
#
# Write a function that takes an image path as input and returns the dog breed (`Affenpinscher`, `Afghan hound`, etc) that is predicted by your model.

# %%
### TODO: Write a function that takes a path to an image as input
### and returns the dog breed that is predicted by the model.

# list of class names by index, i.e. a name can be accessed like class_names[0]
data_transfer = {k: loader.dataset for k, loader in loaders_transfer.items()}
class_names = [item[4:].replace("_", " ") for item in data_transfer['train'].classes]

def predict_breed_transfer(img_path):
    img_raw = Image.open(img_path)
    
    transformations = transforms.Compose([
        transforms.Resize(RESIZE_DIMS),
        transforms.ToTensor()
    ])
    
    img = transformations(img_raw)
    img = img[None]
    
    if use_cuda:
        img = img.cuda()
    
    prediction = model_transfer(img)
    
    prob, index = prediction[0, :].max(0)
    return class_names[index]

# %% [markdown]
# ---
# <a id='step5'></a>
# ## Step 5: Write your Algorithm
#
# Write an algorithm that accepts a file path to an image and first determines whether the image contains a human, dog, or neither.  Then,
# - if a __dog__ is detected in the image, return the predicted breed.
# - if a __human__ is detected in the image, return the resembling dog breed.
# - if __neither__ is detected in the image, provide output that indicates an error.
#
# You are welcome to write your own functions for detecting humans and dogs in images, but feel free to use the `face_detector` and `dog_detector` functions developed above.  You are __required__ to use your CNN from Step 4 to predict dog breed.
#
# Some sample output for our algorithm is provided below, but feel free to design your own user experience!
#
# ![Sample Human Output](images/sample_human_output.png)
#
#
# ### (IMPLEMENTATION) Write your Algorithm

# %%
### TODO: Write your algorithm.
### Feel free to use as many code cells as needed.
from matplotlib import pyplot as plt
import matplotlib.image as mpimg 

def sample_dog(breed):
    idx = class_names.index(breed)
    dog_imgs = loaders_transfer['train'].dataset.imgs
    breed_imgs = [img_path for (img_path, class_idx) in dog_imgs if class_idx == idx]
    dog_sample = breed_imgs[0]
    
    return dog_sample

def run_app(img_path):
    ## handle cases for a human face, dog, and neither
    fig = plt.figure(figsize=(8, 8))
    
    breed = predict_breed_transfer(img_path)
    
    img = mpimg.imread(img_path)
    
    fig.add_subplot(1, 2, 1)
    imgplot = plt.imshow(img)
    
    if dog_detector(img_path):
        msg = 'This dog is a {}'.format(breed)
        
    elif face_detector(img_path):
        msg = 'This human looks like a {}'.format(breed)
        
    else:
        msg = 'What are you doing here?'
        
    plt.title(msg) 
    
    fig.add_subplot(1, 2, 2)
    dog_img = mpimg.imread(sample_dog(breed))
    dog_imgplot = plt.imshow(dog_img)
    plt.show()

# %% [markdown]
# ---
# <a id='step6'></a>
# ## Step 6: Test Your Algorithm
#
# In this section, you will take your new algorithm for a spin!  What kind of dog does the algorithm think that _you_ look like?  If you have a dog, does it predict your dog's breed accurately?  If you have a cat, does it mistakenly think that your cat is a dog?
#
# ### (IMPLEMENTATION) Test Your Algorithm on Sample Images!
#
# Test your algorithm at least six images on your computer.  Feel free to use any images you like.  Use at least two human and two dog images.
#
# __Question 6:__ Is the output better than you expected :) ?  Or worse :( ?  Provide at least three possible points of improvement for your algorithm.

# %% [markdown]
# __Answer:__ (Three possible points for improvement)
#
# From the test function, I was expecting it to perform a bit better. For the human images, it seems to be predicting Dogue de burdeux to frequently. It's also not detecting dogs in the sample images. In it's defense, they're not conventional dogs pictures.
#
# 1. Use a web interface where people can upload a picture and get a response
# 2. Use only the croped area from the detectors to predict the breed
# 3. Use a bigger batch size (with bigger/multiple GPU). I had to train this on a modest GeForce GTX 1050

# %%
## TODO: Execute your algorithm from Step 6 on
## at least 6 images on your computer.
## Feel free to use as many code cells as needed.

import numpy as np
from glob import glob

## suggested code, below
files = np.array(glob('sampleImages/*'))
for file in files:
    run_app(file)
