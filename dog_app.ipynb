# %% [markdown]
# # Convolutional Neural Networks
#
# ## Project: Write an Algorithm for a Dog Identification App
#
# ---
#
# In this notebook, some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this project. You will not need to modify the included code beyond what is requested. Sections that begin with **'(IMPLEMENTATION)'** in the header indicate that the following block of code will require additional functionality which you must provide. Instructions will be provided for each section, and the specifics of the implementation are marked in the code block with a 'TODO' statement. Please be sure to read the instructions carefully!
#
# > **Note**: Once you have completed all of the code implementations, you need to finalize your work by exporting the Jupyter Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You can then export the notebook by using the menu above and navigating to **File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question X'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut.  Markdown cells can be edited by double-clicking the cell to enter edit mode.
#
# The rubric contains _optional_ "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. If you decide to pursue the "Stand Out Suggestions", you should include the code in this Jupyter notebook.
#
#
#
# ---
# ### Why We're Here
#
# In this notebook, you will make the first steps towards developing an algorithm that could be used as part of a mobile or web app.  At the end of this project, your code will accept any user-supplied image as input.  If a dog is detected in the image, it will provide an estimate of the dog's breed.  If a human is detected, it will provide an estimate of the dog breed that is most resembling.  The image below displays potential sample output of your finished project (... but we expect that each student's algorithm will behave differently!).
#
# ![Sample Dog Output](images/sample_dog_output.png)
#
# In this real-world setting, you will need to piece together a series of models to perform different tasks; for instance, the algorithm that detects humans in an image will be different from the CNN that infers dog breed.  There are many points of possible failure, and no perfect algorithm exists.  Your imperfect solution will nonetheless create a fun user experience!
#
# ### The Road Ahead
#
# We break the notebook into separate steps.  Feel free to use the links below to navigate the notebook.
#
# * [Step 0](#step0): Import Datasets
# * [Step 1](#step1): Detect Humans
# * [Step 2](#step2): Detect Dogs
# * [Step 3](#step3): Create a CNN to Classify Dog Breeds (from Scratch)
# * [Step 4](#step4): Create a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 5](#step5): Write your Algorithm
# * [Step 6](#step6): Test Your Algorithm
#
# ---
# <a id='step0'></a>
# ## Step 0: Import Datasets
#
# Make sure that you've downloaded the required human and dog datasets:
# * Download the [dog dataset](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/dogImages.zip).  Unzip the folder and place it in this project's home directory, at the location `/dogImages`.
#
# * Download the [human dataset](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/lfw.zip).  Unzip the folder and place it in the home directory, at location `/lfw`.
#
# *Note: If you are using a Windows machine, you are encouraged to use [7zip](http://www.7-zip.org/) to extract the folder.*
#
# In the code cell below, we save the file paths for both the human (LFW) dataset and dog dataset in the numpy arrays `human_files` and `dog_files`.

# %%
import numpy as np
from glob import glob

# load filenames for human and dog images
human_files = np.array(glob("lfw/*/*"))
dog_files = np.array(glob("dogImages/*/*/*"))

# print number of images in each dataset
print('There are %d total human images.' % len(human_files))
print('There are %d total dog images.' % len(dog_files))
# Out:
# There are 13234 total human images.
# There are 8351 total dog images.

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Detect Humans
#
# In this section, we use OpenCV's implementation of [Haar feature-based cascade classifiers](http://docs.opencv.org/trunk/d7/d8b/tutorial_py_face_detection.html) to detect human faces in images.
#
# OpenCV provides many pre-trained face detectors, stored as XML files on [github](https://github.com/opencv/opencv/tree/master/data/haarcascades).  We have downloaded one of these detectors and stored it in the `haarcascades` directory.  In the next code cell, we demonstrate how to use this detector to find human faces in a sample image.

# %%
import cv2                
import matplotlib.pyplot as plt                        
# %matplotlib inline                               

# extract pre-trained face detector
face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')

# load color (BGR) image
img = cv2.imread(human_files[0])
# convert BGR image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# find faces in image
faces = face_cascade.detectMultiScale(gray)

# print number of faces detected in the image
print('Number of faces detected:', len(faces))

# get bounding box for each detected face
for (x,y,w,h) in faces:
    # add bounding box to color image
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    
# convert BGR image to RGB for plotting
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# display the image, along with bounding box
plt.imshow(cv_rgb)
plt.show()
# Out:
# Number of faces detected: 1

# %% [markdown]
# Before using any of the face detectors, it is standard procedure to convert the images to grayscale.  The `detectMultiScale` function executes the classifier stored in `face_cascade` and takes the grayscale image as a parameter.
#
# In the above code, `faces` is a numpy array of detected faces, where each row corresponds to a detected face.  Each detected face is a 1D array with four entries that specifies the bounding box of the detected face.  The first two entries in the array (extracted in the above code as `x` and `y`) specify the horizontal and vertical positions of the top left corner of the bounding box.  The last two entries in the array (extracted here as `w` and `h`) specify the width and height of the box.
#
# ### Write a Human Face Detector
#
# We can use this procedure to write a function that returns `True` if a human face is detected in an image and `False` otherwise.  This function, aptly named `face_detector`, takes a string-valued file path to an image as input and appears in the code block below.

# %%
# returns "True" if face is detected in image stored at img_path
def face_detector(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
    return len(faces) > 0

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Human Face Detector
#
# __Question 1:__ Use the code cell below to test the performance of the `face_detector` function.
# - What percentage of the first 100 images in `human_files` have a detected human face?
# - What percentage of the first 100 images in `dog_files` have a detected human face?
#
# Ideally, we would like 100% of human images with a detected face and 0% of dog images with a detected face.  You will see that our algorithm falls short of this goal, but still gives acceptable performance.  We extract the file paths for the first 100 images from each of the datasets and store them in the numpy arrays `human_files_short` and `dog_files_short`.

# %% [markdown]
# __Answer:__
# (You can print out your results and/or write your percentages in this cell)

# %%
from tqdm import tqdm

human_files_short = human_files[:100]
dog_files_short = dog_files[:100]

#-#-# Do NOT modify the code above this line. #-#-#

## TODO: Test the performance of the face_detector algorithm 
## on the images in human_files_short and dog_files_short.

face_detector_vectorized = np.vectorize(face_detector)

face_detected_in_human_files = np.round(face_detector_vectorized(human_files_short).mean() * 100)
face_detected_in_dog_files = np.round(face_detector_vectorized(dog_files_short).mean() * 100)

print('Detected faces in {}% of human files'.format(face_detected_in_human_files))
print('Detected faces in {}% dog files'.format(face_detected_in_dog_files))
# Out:
# Detected faces in 96.0% of human files
# Detected faces in 18.0% dog files

# %% [markdown]
# We suggest the face detector from OpenCV as a potential way to detect human images in your algorithm, but you are free to explore other approaches, especially approaches that make use of deep learning :).  Please use the code cell below to design and test your own face detection algorithm.  If you decide to pursue this _optional_ task, report performance on `human_files_short` and `dog_files_short`.

# %%
### (Optional) 
### TODO: Test performance of another face detection algorithm.
### Feel free to use as many code cells as needed.

# %% [markdown]
# ---
# <a id='step2'></a>
# ## Step 2: Detect Dogs
#
# In this section, we use a [pre-trained model](http://pytorch.org/docs/master/torchvision/models.html) to detect dogs in images.
#
# ### Obtain Pre-trained VGG-16 Model
#
# The code cell below downloads the VGG-16 model, along with weights that have been trained on [ImageNet](http://www.image-net.org/), a very large, very popular dataset used for image classification and other vision tasks.  ImageNet contains over 10 million URLs, each linking to an image containing an object from one of [1000 categories](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).

# %%
import torch
import torchvision.models as models

# define VGG16 model
VGG16 = models.vgg16(pretrained=True)

# check if CUDA is available
use_cuda = torch.cuda.is_available()

# move model to GPU if CUDA is available
if use_cuda:
    print('Cuda is available. Switching to CUDA')
    VGG16 = VGG16.cuda()
    
print(VGG16)
# Out:
# Cuda is available. Switching to CUDA
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace)
#     (2): Dropout(p=0.5)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace)
#     (5): Dropout(p=0.5)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %% [markdown]
# Given an image, this pre-trained VGG-16 model returns a prediction (derived from the 1000 possible categories in ImageNet) for the object that is contained in the image.

# %% [markdown]
# ### (IMPLEMENTATION) Making Predictions with a Pre-trained Model
#
# In the next code cell, you will write a function that accepts a path to an image (such as `'dogImages/train/001.Affenpinscher/Affenpinscher_00001.jpg'`) as input and returns the index corresponding to the ImageNet class that is predicted by the pre-trained VGG-16 model.  The output should always be an integer between 0 and 999, inclusive.
#
# Before writing the function, make sure that you take the time to learn  how to appropriately pre-process tensors for pre-trained models in the [PyTorch documentation](http://pytorch.org/docs/stable/torchvision/models.html).

# %%
from PIL import Image
import torchvision.transforms as transforms

# Set PIL to be tolerant of image files that are truncated.
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True


RESIZE_DIMS = (256, 256)


def VGG16_predict(img_path):
    '''
    Use pre-trained VGG-16 model to obtain index corresponding to 
    predicted ImageNet class for image at specified path
    
    Args:
        img_path: path to an image
        
    Returns:
        Index corresponding to VGG-16 model's prediction
    '''
    
    ## TODO: Complete the function.
    ## Load and pre-process an image from the given img_path
    ## Return the *index* of the predicted class for that image
    img_raw = Image.open(img_path)
    
    transformations = transforms.Compose([
        transforms.Resize(RESIZE_DIMS),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225])
    ])
    
    img = transformations(img_raw)
    img = img[None]
    
    if use_cuda:
        img = img.cuda()
    
    prediction = VGG16(img)
    
    prob, index = prediction[0, :].max(0)
    return int(index)

# %% [markdown]
# ### (IMPLEMENTATION) Write a Dog Detector
#
# While looking at the [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a), you will notice that the categories corresponding to dogs appear in an uninterrupted sequence and correspond to dictionary keys 151-268, inclusive, to include all categories from `'Chihuahua'` to `'Mexican hairless'`.  Thus, in order to check to see if an image is predicted to contain a dog by the pre-trained VGG-16 model, we need only check if the pre-trained model predicts an index between 151 and 268 (inclusive).
#
# Use these ideas to complete the `dog_detector` function below, which returns `True` if a dog is detected in an image (and `False` if not).

# %%
### returns "True" if a dog is detected in the image stored at img_path
def dog_detector(img_path):
    ## TODO: Complete the function.
    
    return (151 <= VGG16_predict(img_path) <= 268)  # true/false

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Dog Detector
#
# __Question 2:__ Use the code cell below to test the performance of your `dog_detector` function.
# - What percentage of the images in `human_files_short` have a detected dog?
# - What percentage of the images in `dog_files_short` have a detected dog?

# %% [markdown]
# __Answer:__

# %%
### TODO: Test the performance of the dog_detector function
### on the images in human_files_short and dog_files_short.
dog_detector_vectorized = np.vectorize(dog_detector)

dog_detected_in_human_files = np.round(dog_detector_vectorized(human_files_short).mean() * 100)
print('Detected dogs in {}% of human files'.format(dog_detected_in_human_files))
del dog_detected_in_human_files

dog_detected_in_dog_files = np.round(dog_detector_vectorized(dog_files_short).mean() * 100)
print('Detected dogs in {}% dog files'.format(dog_detected_in_dog_files))
del dog_detected_in_dog_files
# Out:
# Detected dogs in 0.0% of human files
# Detected dogs in 94.0% dog files

# %% [markdown]
# We suggest VGG-16 as a potential network to detect dog images in your algorithm, but you are free to explore other pre-trained networks (such as [Inception-v3](http://pytorch.org/docs/master/torchvision/models.html#inception-v3), [ResNet-50](http://pytorch.org/docs/master/torchvision/models.html#id3), etc).  Please use the code cell below to test other pre-trained PyTorch models.  If you decide to pursue this _optional_ task, report performance on `human_files_short` and `dog_files_short`.

# %%
### (Optional) 
### TODO: Report the performance of another pre-trained network.
### Feel free to use as many code cells as needed.

# %% [markdown]
# ---
# <a id='step3'></a>
# ## Step 3: Create a CNN to Classify Dog Breeds (from Scratch)
#
# Now that we have functions for detecting humans and dogs in images, we need a way to predict breed from images.  In this step, you will create a CNN that classifies dog breeds.  You must create your CNN _from scratch_ (so, you can't use transfer learning _yet_!), and you must attain a test accuracy of at least 10%.  In Step 4 of this notebook, you will have the opportunity to use transfer learning to create a CNN that attains greatly improved accuracy.
#
# We mention that the task of assigning breed to dogs from images is considered exceptionally challenging.  To see why, consider that *even a human* would have trouble distinguishing between a Brittany and a Welsh Springer Spaniel.
#
# Brittany | Welsh Springer Spaniel
# - | -
# <img src="images/Brittany_02625.jpg" width="100"> | <img src="images/Welsh_springer_spaniel_08203.jpg" width="200">
#
# It is not difficult to find other dog breed pairs with minimal inter-class variation (for instance, Curly-Coated Retrievers and American Water Spaniels).
#
# Curly-Coated Retriever | American Water Spaniel
# - | -
# <img src="images/Curly-coated_retriever_03896.jpg" width="200"> | <img src="images/American_water_spaniel_00648.jpg" width="200">
#
#
# Likewise, recall that labradors come in yellow, chocolate, and black.  Your vision-based algorithm will have to conquer this high intra-class variation to determine how to classify all of these different shades as the same breed.
#
# Yellow Labrador | Chocolate Labrador | Black Labrador
# - | -
# <img src="images/Labrador_retriever_06457.jpg" width="150"> | <img src="images/Labrador_retriever_06455.jpg" width="240"> | <img src="images/Labrador_retriever_06449.jpg" width="220">
#
# We also mention that random chance presents an exceptionally low bar: setting aside the fact that the classes are slightly imabalanced, a random guess will provide a correct answer roughly 1 in 133 times, which corresponds to an accuracy of less than 1%.
#
# Remember that the practice is far ahead of the theory in deep learning.  Experiment with many different architectures, and trust your intuition.  And, of course, have fun!
#
# ### (IMPLEMENTATION) Specify Data Loaders for the Dog Dataset
#
# Use the code cell below to write three separate [data loaders](http://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader) for the training, validation, and test datasets of dog images (located at `dogImages/train`, `dogImages/valid`, and `dogImages/test`, respectively).  You may find [this documentation on custom datasets](http://pytorch.org/docs/stable/torchvision/datasets.html) to be a useful resource.  If you are interested in augmenting your training and/or validation data, check out the wide variety of [transforms](http://pytorch.org/docs/stable/torchvision/transforms.html?highlight=transform)!

# %%
import os
from torchvision import datasets

### TODO: Write data loaders for training, validation, and test sets
## Specify appropriate transforms, and batch_sizes


loaders_scratch = {}
BATCH_SIZE = 4

# Train set
train_transforms = transforms.Compose([
    transforms.Resize(RESIZE_DIMS),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(20),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])
train_folder = datasets.ImageFolder('dogImages/train/', transform=train_transforms)
loaders_scratch['train'] = torch.utils.data.DataLoader(train_folder,
                                           batch_size=BATCH_SIZE,
                                           shuffle=True)

# Validation set
valid_transforms = transforms.Compose([
    transforms.Resize(RESIZE_DIMS),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(20),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])
valid_folder = datasets.ImageFolder('dogImages/valid/', transform=valid_transforms)
loaders_scratch['valid'] = torch.utils.data.DataLoader(valid_folder,
                                                       batch_size=BATCH_SIZE,
                                                       shuffle=True)

# Test set
test_transforms = transforms.Compose([
    transforms.Resize(RESIZE_DIMS),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])
test_folder = datasets.ImageFolder('dogImages/test/', transform=test_transforms)
loaders_scratch['test'] = torch.utils.data.DataLoader(test_folder,
                                           batch_size=BATCH_SIZE,
                                           shuffle=True)

# %% [markdown]
# **Question 3:** Describe your chosen procedure for preprocessing the data.
# - How does your code resize the images (by cropping, stretching, etc)?  What size did you pick for the input tensor, and why?
# - Did you decide to augment the dataset?  If so, how (through translations, flips, rotations, etc)?  If not, why not?

# %% [markdown]
# **Answer**:
#
# - I resize images to the same size accross the whole project using the constant `RESIZE_DIMS = (256, 256)`. This size is compatible with VGG16 and also is a power of two, which makes easier to compute output sizes. This size is achieved by stretching the image. I prefer this way because it minimizes the possibility of loosing some

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  Use the template in the code cell below.

# %%
import torch.nn as nn
import torch.nn.functional as F

# define the CNN architecture
class Net(nn.Module):
    ### TODO: choose an architecture, and complete the class
    def __init__(self):
        super(Net, self).__init__()
        
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=64, kernel_size=(3, 3), stride=1, padding=1)
        self.conv2 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=(3, 3), stride=1, padding=1)
        
        self.conv3 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=(3, 3), stride=1, padding=1)
        self.conv4 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=(3, 3), stride=1, padding=1)
        self.conv5 = nn.Conv2d(in_channels=256, out_channels=512, kernel_size=(3, 3), stride=1, padding=1)
        
        self.fc1 = nn.Linear(4 * 4 * 512, 4096)
        self.fc2 = nn.Linear(4096, 4096)
        self.fc3 = nn.Linear(4096, 133)
        
        self.pool = nn.MaxPool2d(kernel_size=(2, 2), stride=2)
        self.pool4 = nn.MaxPool2d(kernel_size=(4, 4), stride=4)
        self.drop = nn.Dropout(0.25)
        
    
    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.pool4(x)
        
        x = self.conv2(x)
        x = F.relu(x)
        x = self.pool(x)
        
        x = self.conv3(x)
        x = F.relu(x)
        x = self.pool(x)
        
        x = self.conv4(x)
        x = F.relu(x)
        x = self.pool(x)
        
        x = self.conv5(x)
        x = F.relu(x)
        x = self.pool(x)
        
        x = x.view(-1, 4 * 4 * 512)
        x = self.drop(x)
        
        x = self.fc1(x)
        x = F.relu(x)
        x = self.drop(x)
        
        x = self.fc2(x)
        x = F.relu(x)
        x = self.drop(x)
        
        return x

#-#-# You do NOT have to modify the code below this line. #-#-#

# instantiate the CNN
model_scratch = Net()

# move tensors to GPU if CUDA is available
if use_cuda:
    model_scratch.cuda()

# %% [markdown]
# __Question 4:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.

# %% [markdown]
# __Answer:__
#
# I took a peek into the VGG16 architecture to get some ideas, as this architecture has been succesfully applied to other computer vision problems.
#
# **Features layers**
#
# I'm using convolution layers to extract _features_ or patterns from the images, starting with 64 _filters_ in the first layer, and going to up to 512. The first two layers are connected directly and then comes a max pooling layer. All other convolutional layers are followed by a maxpooling layer, so each one is _narrower_ and _deeper_. All of the layers use a ReLU activation function.
#
# **CLassification layers**
#
# Finally, the ouput of the last convolutional layer is flatten and then passed to two consecutive fully connected layers with 4096 neurons. These layers have a 25% dropout and use a ReLU activation function.

# %% [markdown]
# ### (IMPLEMENTATION) Specify Loss Function and Optimizer
#
# Use the next code cell to specify a [loss function](http://pytorch.org/docs/stable/nn.html#loss-functions) and [optimizer](http://pytorch.org/docs/stable/optim.html).  Save the chosen loss function as `criterion_scratch`, and the optimizer as `optimizer_scratch` below.

# %%
import torch.optim as optim

### TODO: select loss function
criterion_scratch = nn.CrossEntropyLoss()

### TODO: select optimizer
optimizer_scratch = optim.SGD(model_scratch.parameters(), lr=0.001)

# %% [markdown]
# ### (IMPLEMENTATION) Train and Validate the Model
#
# Train and validate your model in the code cell below.  [Save the final model parameters](http://pytorch.org/docs/master/notes/serialization.html) at filepath `'model_scratch.pt'`.

# %%
# the following import is required for training to be robust to truncated images
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

N_EPOCHS = 100
STEPS_PER_EPOCH = 133 * 10

data = torch.empty((BATCH_SIZE, 3) + RESIZE_DIMS)
target = torch.empty((133, ))
output = torch.empty((133, ))
loss = torch.empty((1, ))

def train(n_epochs, loaders, model, optimizer, criterion, use_cuda, save_path):
    """returns trained model"""
    print('Training model...')
    # initialize tracker for minimum validation loss
    valid_loss_min = np.Inf 
    
    for epoch in range(1, n_epochs+1):
        memory_allocated = torch.cuda.memory_allocated()
        print('Starting epoch {}/{}. Memory allocated: {}'.format(
            epoch,
            n_epochs,
            memory_allocated
        ))
        
        # initialize variables to monitor training and validation loss
        train_loss = 0.0
        valid_loss = 0.0
        
        ###################
        # train the model #
        ###################
        model.train()
        batch_idx = 1
        for data, target in loaders['train']:
            # move to GPU
            if use_cuda:
                data, target = data.cuda(), target.cuda()
            ## find the loss and update the model parameters accordingly
            ## record the average training loss, using something like
            ## train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
            
            optimizer.zero_grad()
            output = model(data)
            
            loss = criterion(output, target)

            loss.backward()
            optimizer.step()
            train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
            
            if batch_idx >= STEPS_PER_EPOCH:
                break
                
            batch_idx += 1
            
            
        ######################    
        # validate the model #
        ######################
        model.eval()
        batch_idx = 1
        for data, target in loaders['valid']:
                
            # move to GPU
            if use_cuda:
                data, target = data.cuda(), target.cuda()
            
            ## update the average validation loss
            output = model(data)
            # calculate the batch loss
            loss = criterion(output, target)
            
            # update average validation loss 
            valid_loss = valid_loss + ((1 / (batch_idx + 1)) * (loss.data - valid_loss))
            
            if batch_idx >= STEPS_PER_EPOCH:
                break
                
            batch_idx += 1
        
        # print training/validation statistics 
        memory_allocated = torch.cuda.memory_allocated()
        print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f} \tMemory allocated: {}'.format(
            epoch, 
            train_loss,
            valid_loss,
            memory_allocated
            ))
        
        ## TODO: save the model if validation loss has decreased
        if valid_loss <= valid_loss_min:
            print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
            valid_loss_min,
            valid_loss))
            torch.save(model.state_dict(), save_path)
            valid_loss_min = valid_loss
            
    # return trained model
    return model


# train the model
model_scratch = train(N_EPOCHS, loaders_scratch, model_scratch, optimizer_scratch, 
                      criterion_scratch, use_cuda, 'model_scratch.pt')

# load the model that got the best validation accuracy
model_scratch.load_state_dict(torch.load('model_scratch.pt'))
# Out:
# Training model...
# Starting epoch 1/100. Memory allocated: 764761600
# Epoch: 1 	Training Loss: 8.294983 	Validation Loss: 8.219150 	Memory allocated: 1105989120
# Validation loss decreased (inf --> 8.219150).  Saving model ...
# Starting epoch 2/100. Memory allocated: 1105989120
# Epoch: 2 	Training Loss: 7.037322 	Validation Loss: 6.079129 	Memory allocated: 1105989632
# Validation loss decreased (8.219150 --> 6.079129).  Saving model ...
# Starting epoch 3/100. Memory allocated: 1105989120
# Epoch: 3 	Training Loss: 6.410647 	Validation Loss: 5.780022 	Memory allocated: 1105989632
# Validation loss decreased (6.079129 --> 5.780022).  Saving model ...
# Starting epoch 4/100. Memory allocated: 1105989120
# Epoch: 4 	Training Loss: 6.320948 	Validation Loss: 5.659359 	Memory allocated: 1105989632
# Validation loss decreased (5.780022 --> 5.659359).  Saving model ...
# Starting epoch 5/100. Memory allocated: 1105989120
# Epoch: 5 	Training Loss: 6.272050 	Validation Loss: 5.749911 	Memory allocated: 1105989632
# Starting epoch 6/100. Memory allocated: 1105989632
# Epoch: 6 	Training Loss: 6.290818 	Validation Loss: 5.739569 	Memory allocated: 1105989632
# Starting epoch 7/100. Memory allocated: 1105989632
# Epoch: 7 	Training Loss: 6.247384 	Validation Loss: 5.639756 	Memory allocated: 1105989632
# Validation loss decreased (5.659359 --> 5.639756).  Saving model ...
# Starting epoch 8/100. Memory allocated: 1105989120
# Epoch: 8 	Training Loss: 6.240199 	Validation Loss: 5.714680 	Memory allocated: 1105989632
# Starting epoch 9/100. Memory allocated: 1105989632
# Epoch: 9 	Training Loss: 6.160405 	Validation Loss: 5.508209 	Memory allocated: 1105989632
# Validation loss decreased (5.639756 --> 5.508209).  Saving model ...
# Starting epoch 10/100. Memory allocated: 1105989120
# Epoch: 10 	Training Loss: 6.128050 	Validation Loss: 5.381463 	Memory allocated: 1105989632
# Validation loss decreased (5.508209 --> 5.381463).  Saving model ...
# Starting epoch 11/100. Memory allocated: 1105989120
# Epoch: 11 	Training Loss: 6.090954 	Validation Loss: 5.464269 	Memory allocated: 1105989632
# Starting epoch 12/100. Memory allocated: 1105989632
# Epoch: 12 	Training Loss: 5.988298 	Validation Loss: 5.477176 	Memory allocated: 1105989632
# Starting epoch 13/100. Memory allocated: 1105989632
# Epoch: 13 	Training Loss: 5.949107 	Validation Loss: 5.178348 	Memory allocated: 1105989632
# Validation loss decreased (5.381463 --> 5.178348).  Saving model ...
# Starting epoch 14/100. Memory allocated: 1105989120
# Epoch: 14 	Training Loss: 5.952292 	Validation Loss: 5.382707 	Memory allocated: 1105989632
# Starting epoch 15/100. Memory allocated: 1105989632
# Epoch: 15 	Training Loss: 5.929791 	Validation Loss: 5.254407 	Memory allocated: 1105989632
# Starting epoch 16/100. Memory allocated: 1105989632
# Epoch: 16 	Training Loss: 5.865946 	Validation Loss: 5.102792 	Memory allocated: 1105989632
# Validation loss decreased (5.178348 --> 5.102792).  Saving model ...
# Starting epoch 17/100. Memory allocated: 1105989120
# Epoch: 17 	Training Loss: 5.866297 	Validation Loss: 5.102650 	Memory allocated: 1105989632
# Validation loss decreased (5.102792 --> 5.102650).  Saving model ...
# Starting epoch 18/100. Memory allocated: 1105989120
# Epoch: 18 	Training Loss: 5.797510 	Validation Loss: 5.335501 	Memory allocated: 1105989632
# Starting epoch 19/100. Memory allocated: 1105989632
# Epoch: 19 	Training Loss: 5.730289 	Validation Loss: 5.067586 	Memory allocated: 1105989632
# Validation loss decreased (5.102650 --> 5.067586).  Saving model ...
# Starting epoch 20/100. Memory allocated: 1105989120
# Epoch: 20 	Training Loss: 5.789789 	Validation Loss: 5.057208 	Memory allocated: 1105989632
# Validation loss decreased (5.067586 --> 5.057208).  Saving model ...
# Starting epoch 21/100. Memory allocated: 1105989120
# Epoch: 21 	Training Loss: 5.735564 	Validation Loss: 5.475204 	Memory allocated: 1105989632
# Starting epoch 22/100. Memory allocated: 1105989632
# Epoch: 22 	Training Loss: 5.638578 	Validation Loss: 5.093751 	Memory allocated: 1105989632
# Starting epoch 23/100. Memory allocated: 1105989632
# Epoch: 23 	Training Loss: 5.650419 	Validation Loss: 5.162100 	Memory allocated: 1105989632
# Starting epoch 24/100. Memory allocated: 1105989632
# Epoch: 24 	Training Loss: 5.645723 	Validation Loss: 4.898565 	Memory allocated: 1105989632
# Validation loss decreased (5.057208 --> 4.898565).  Saving model ...
# Starting epoch 25/100. Memory allocated: 1105989120
# Epoch: 25 	Training Loss: 5.605208 	Validation Loss: 5.241484 	Memory allocated: 1105989632
# Starting epoch 26/100. Memory allocated: 1105989632
# Epoch: 26 	Training Loss: 5.577194 	Validation Loss: 4.971087 	Memory allocated: 1105989632
# Starting epoch 27/100. Memory allocated: 1105989632
# Epoch: 27 	Training Loss: 5.539871 	Validation Loss: 4.803556 	Memory allocated: 1105989632
# Validation loss decreased (4.898565 --> 4.803556).  Saving model ...
# Starting epoch 28/100. Memory allocated: 1105989120
# Epoch: 28 	Training Loss: 5.566864 	Validation Loss: 5.128936 	Memory allocated: 1105989632
# Starting epoch 29/100. Memory allocated: 1105989632
# Epoch: 29 	Training Loss: 5.493054 	Validation Loss: 5.065745 	Memory allocated: 1105989632
# Starting epoch 30/100. Memory allocated: 1105989632
# Epoch: 30 	Training Loss: 5.425402 	Validation Loss: 4.761907 	Memory allocated: 1105989632
# Validation loss decreased (4.803556 --> 4.761907).  Saving model ...
# Starting epoch 31/100. Memory allocated: 1105989120
# Epoch: 31 	Training Loss: 5.464836 	Validation Loss: 4.933932 	Memory allocated: 1105989632
# Starting epoch 32/100. Memory allocated: 1105989632
# Epoch: 32 	Training Loss: 5.414546 	Validation Loss: 4.843002 	Memory allocated: 1105989632
# Starting epoch 33/100. Memory allocated: 1105989632
# Epoch: 33 	Training Loss: 5.447149 	Validation Loss: 4.921651 	Memory allocated: 1105989632
# Starting epoch 34/100. Memory allocated: 1105989632
# Epoch: 34 	Training Loss: 5.421510 	Validation Loss: 5.010839 	Memory allocated: 1105989632
# Starting epoch 35/100. Memory allocated: 1105989632
# Epoch: 35 	Training Loss: 5.401412 	Validation Loss: 4.788456 	Memory allocated: 1105989632
# Starting epoch 36/100. Memory allocated: 1105989632
# Epoch: 36 	Training Loss: 5.333504 	Validation Loss: 4.661132 	Memory allocated: 1105989632
# Validation loss decreased (4.761907 --> 4.661132).  Saving model ...
# Starting epoch 37/100. Memory allocated: 1105989120
# Epoch: 37 	Training Loss: 5.301552 	Validation Loss: 4.646843 	Memory allocated: 1105989632
# Validation loss decreased (4.661132 --> 4.646843).  Saving model ...
# Starting epoch 38/100. Memory allocated: 1105989120
# Epoch: 38 	Training Loss: 5.286556 	Validation Loss: 4.870145 	Memory allocated: 1105989632
# Starting epoch 39/100. Memory allocated: 1105989632
# Epoch: 39 	Training Loss: 5.272501 	Validation Loss: 5.058409 	Memory allocated: 1105989632
# Starting epoch 40/100. Memory allocated: 1105989632
# Epoch: 40 	Training Loss: 5.214790 	Validation Loss: 4.532902 	Memory allocated: 1105989632
# Validation loss decreased (4.646843 --> 4.532902).  Saving model ...
# Starting epoch 41/100. Memory allocated: 1105989120
# Epoch: 41 	Training Loss: 5.176696 	Validation Loss: 4.711359 	Memory allocated: 1105989632
# Starting epoch 42/100. Memory allocated: 1105989632
# Epoch: 42 	Training Loss: 5.195732 	Validation Loss: 4.833848 	Memory allocated: 1105989632
# Starting epoch 43/100. Memory allocated: 1105989632
# Epoch: 43 	Training Loss: 5.135505 	Validation Loss: 4.731555 	Memory allocated: 1105989632
# Starting epoch 44/100. Memory allocated: 1105989632
# Epoch: 44 	Training Loss: 5.081985 	Validation Loss: 4.835503 	Memory allocated: 1105989632
# Starting epoch 45/100. Memory allocated: 1105989632
# Epoch: 45 	Training Loss: 5.030770 	Validation Loss: 4.836207 	Memory allocated: 1105989632
# Starting epoch 46/100. Memory allocated: 1105989632
# Epoch: 46 	Training Loss: 5.034268 	Validation Loss: 4.504286 	Memory allocated: 1105989632
# Validation loss decreased (4.532902 --> 4.504286).  Saving model ...
# Starting epoch 47/100. Memory allocated: 1105989120
# Epoch: 47 	Training Loss: 4.959944 	Validation Loss: 4.776164 	Memory allocated: 1105989632
# Starting epoch 48/100. Memory allocated: 1105989632
# Epoch: 48 	Training Loss: 5.003157 	Validation Loss: 4.610652 	Memory allocated: 1105989632
# Starting epoch 49/100. Memory allocated: 1105989632
# Epoch: 49 	Training Loss: 4.940370 	Validation Loss: 4.880407 	Memory allocated: 1105989632
# Starting epoch 50/100. Memory allocated: 1105989632
# Epoch: 50 	Training Loss: 4.896804 	Validation Loss: 4.479043 	Memory allocated: 1105989632
# Validation loss decreased (4.504286 --> 4.479043).  Saving model ...
# Starting epoch 51/100. Memory allocated: 1105989120
# Epoch: 51 	Training Loss: 4.801935 	Validation Loss: 4.658072 	Memory allocated: 1105989632
# Starting epoch 52/100. Memory allocated: 1105989632
# Epoch: 52 	Training Loss: 4.834568 	Validation Loss: 4.728518 	Memory allocated: 1105989632
# Starting epoch 53/100. Memory allocated: 1105989632
# Epoch: 53 	Training Loss: 4.727568 	Validation Loss: 4.464246 	Memory allocated: 1105989632
# Validation loss decreased (4.479043 --> 4.464246).  Saving model ...
# Starting epoch 54/100. Memory allocated: 1105989120
# Epoch: 54 	Training Loss: 4.713024 	Validation Loss: 4.756577 	Memory allocated: 1105989632
# Starting epoch 55/100. Memory allocated: 1105989632
# Epoch: 55 	Training Loss: 4.684810 	Validation Loss: 4.782644 	Memory allocated: 1105989632
# Starting epoch 56/100. Memory allocated: 1105989632
# Epoch: 56 	Training Loss: 4.545372 	Validation Loss: 4.523253 	Memory allocated: 1105989632
# Starting epoch 57/100. Memory allocated: 1105989632
# Epoch: 57 	Training Loss: 4.651382 	Validation Loss: 4.717047 	Memory allocated: 1105989632
# Starting epoch 58/100. Memory allocated: 1105989632
# Epoch: 58 	Training Loss: 4.563425 	Validation Loss: 4.600806 	Memory allocated: 1105989632
# Starting epoch 59/100. Memory allocated: 1105989632
# Epoch: 59 	Training Loss: 4.457383 	Validation Loss: 4.571542 	Memory allocated: 1105989632
# Starting epoch 60/100. Memory allocated: 1105989632
# Epoch: 60 	Training Loss: 4.390544 	Validation Loss: 4.581060 	Memory allocated: 1105989632
# Starting epoch 61/100. Memory allocated: 1105989632
# Epoch: 61 	Training Loss: 4.420185 	Validation Loss: 4.486917 	Memory allocated: 1105989632
# Starting epoch 62/100. Memory allocated: 1105989632
# Epoch: 62 	Training Loss: 4.243798 	Validation Loss: 4.617007 	Memory allocated: 1105989632
# Starting epoch 63/100. Memory allocated: 1105989632
# Epoch: 63 	Training Loss: 4.200320 	Validation Loss: 4.747388 	Memory allocated: 1105989632
# Starting epoch 64/100. Memory allocated: 1105989632
# Epoch: 64 	Training Loss: 4.232251 	Validation Loss: 4.848771 	Memory allocated: 1105989632
# Starting epoch 65/100. Memory allocated: 1105989632
# Epoch: 65 	Training Loss: 4.051793 	Validation Loss: 4.661024 	Memory allocated: 1105989632
# Starting epoch 66/100. Memory allocated: 1105989632
# Epoch: 66 	Training Loss: 4.060639 	Validation Loss: 4.704319 	Memory allocated: 1105989632
# Starting epoch 67/100. Memory allocated: 1105989632
# Epoch: 67 	Training Loss: 3.925757 	Validation Loss: 4.835718 	Memory allocated: 1105989632
# Starting epoch 68/100. Memory allocated: 1105989632
# Epoch: 68 	Training Loss: 3.869172 	Validation Loss: 4.802068 	Memory allocated: 1105989632
# Starting epoch 69/100. Memory allocated: 1105989632
# Epoch: 69 	Training Loss: 3.876974 	Validation Loss: 4.834973 	Memory allocated: 1105989632
# Starting epoch 70/100. Memory allocated: 1105989632
# Epoch: 70 	Training Loss: 3.789620 	Validation Loss: 4.657418 	Memory allocated: 1105989632
# Starting epoch 71/100. Memory allocated: 1105989632
# Epoch: 71 	Training Loss: 3.662459 	Validation Loss: 4.856820 	Memory allocated: 1105989632
# Starting epoch 72/100. Memory allocated: 1105989632
# Epoch: 72 	Training Loss: 3.633630 	Validation Loss: 4.749665 	Memory allocated: 1105989632
# Starting epoch 73/100. Memory allocated: 1105989632
# Epoch: 73 	Training Loss: 3.604657 	Validation Loss: 5.087739 	Memory allocated: 1105989632
# Starting epoch 74/100. Memory allocated: 1105989632
# Epoch: 74 	Training Loss: 3.481461 	Validation Loss: 5.108083 	Memory allocated: 1105989632
# Starting epoch 75/100. Memory allocated: 1105989632
# Epoch: 75 	Training Loss: 3.380752 	Validation Loss: 5.062118 	Memory allocated: 1105989632
# Starting epoch 76/100. Memory allocated: 1105989632
# Epoch: 76 	Training Loss: 3.302563 	Validation Loss: 5.146150 	Memory allocated: 1105989632
# Starting epoch 77/100. Memory allocated: 1105989632
# Epoch: 77 	Training Loss: 3.325011 	Validation Loss: 5.218485 	Memory allocated: 1105989632
# Starting epoch 78/100. Memory allocated: 1105989632
# Epoch: 78 	Training Loss: 3.308713 	Validation Loss: 5.254494 	Memory allocated: 1105989632
# Starting epoch 79/100. Memory allocated: 1105989632
# Epoch: 79 	Training Loss: 3.173045 	Validation Loss: 5.163692 	Memory allocated: 1105989632
# Starting epoch 80/100. Memory allocated: 1105989632
# Epoch: 80 	Training Loss: 3.180854 	Validation Loss: 5.279245 	Memory allocated: 1105989632
# Starting epoch 81/100. Memory allocated: 1105989632
# Epoch: 81 	Training Loss: 2.931516 	Validation Loss: 5.483367 	Memory allocated: 1105989632
# Starting epoch 82/100. Memory allocated: 1105989632
# Epoch: 82 	Training Loss: 3.021457 	Validation Loss: 5.438671 	Memory allocated: 1105989632
# Starting epoch 83/100. Memory allocated: 1105989632
# Epoch: 83 	Training Loss: 3.101041 	Validation Loss: 5.524269 	Memory allocated: 1105989632
# Starting epoch 84/100. Memory allocated: 1105989632
# Epoch: 84 	Training Loss: 2.834529 	Validation Loss: 5.538107 	Memory allocated: 1105989632
# Starting epoch 85/100. Memory allocated: 1105989632
# Epoch: 85 	Training Loss: 2.797563 	Validation Loss: 5.511835 	Memory allocated: 1105989632
# Starting epoch 86/100. Memory allocated: 1105989632
# Epoch: 86 	Training Loss: 2.900142 	Validation Loss: 5.613126 	Memory allocated: 1105989632
# Starting epoch 87/100. Memory allocated: 1105989632
# Epoch: 87 	Training Loss: 2.843271 	Validation Loss: 5.568115 	Memory allocated: 1105989632
# Starting epoch 88/100. Memory allocated: 1105989632
# Epoch: 88 	Training Loss: 2.698301 	Validation Loss: 5.596939 	Memory allocated: 1105989632
# Starting epoch 89/100. Memory allocated: 1105989632
# Epoch: 89 	Training Loss: 2.691365 	Validation Loss: 5.697616 	Memory allocated: 1105989632
# Starting epoch 90/100. Memory allocated: 1105989632
# Epoch: 90 	Training Loss: 2.771170 	Validation Loss: 5.986346 	Memory allocated: 1105989632
# Starting epoch 91/100. Memory allocated: 1105989632
# Epoch: 91 	Training Loss: 2.787890 	Validation Loss: 5.823197 	Memory allocated: 1105989632
# Starting epoch 92/100. Memory allocated: 1105989632
# Epoch: 92 	Training Loss: 2.667407 	Validation Loss: 5.809762 	Memory allocated: 1105989632
# Starting epoch 93/100. Memory allocated: 1105989632
# Epoch: 93 	Training Loss: 2.672994 	Validation Loss: 6.158538 	Memory allocated: 1105989632
# Starting epoch 94/100. Memory allocated: 1105989632
# Epoch: 94 	Training Loss: 2.651077 	Validation Loss: 5.957962 	Memory allocated: 1105989632
# Starting epoch 95/100. Memory allocated: 1105989632
# Epoch: 95 	Training Loss: 2.611722 	Validation Loss: 5.989826 	Memory allocated: 1105989632
# Starting epoch 96/100. Memory allocated: 1105989632
# Epoch: 96 	Training Loss: 2.527288 	Validation Loss: 6.113904 	Memory allocated: 1105989632
# Starting epoch 97/100. Memory allocated: 1105989632
# Epoch: 97 	Training Loss: 2.511865 	Validation Loss: 6.091199 	Memory allocated: 1105989632
# Starting epoch 98/100. Memory allocated: 1105989632
# Epoch: 98 	Training Loss: 2.488723 	Validation Loss: 6.105137 	Memory allocated: 1105989632
# Starting epoch 99/100. Memory allocated: 1105989632
# Epoch: 99 	Training Loss: 2.558193 	Validation Loss: 5.953026 	Memory allocated: 1105989632
# Starting epoch 100/100. Memory allocated: 1105989632
# Epoch: 100 	Training Loss: 2.533653 	Validation Loss: 6.190568 	Memory allocated: 1105989632

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images.  Use the code cell below to calculate and print the test loss and accuracy.  Ensure that your test accuracy is greater than 10%.

# %%
data = torch.empty((BATCH_SIZE, 3) + RESIZE_DIMS)
target = torch.empty((133, ))
output = torch.empty((133, ))


def test(loaders, model, criterion, use_cuda):

    # monitor test loss and accuracy
    test_loss = 0.
    correct = 0.
    total = 0.

    model.eval()
    batch_idx = 1
    for data, target in loaders['test']:
        # move to GPU
        if use_cuda:
            data, target = data.cuda(), target.cuda()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        # update average test loss 
        test_loss = test_loss + ((1 / (batch_idx + 1)) * (loss.data - test_loss))
        # convert output probabilities to predicted class
        pred = output.data.max(1, keepdim=True)[1]
        # compare predictions to true label
        correct += np.sum(np.squeeze(pred.eq(target.data.view_as(pred))).cpu().numpy())
        total += data.size(0)
        batch_idx += 1
            
    print('Test Loss: {:.6f}\n'.format(test_loss))

    print('\nTest Accuracy: %2d%% (%2d/%2d)' % (
        100. * correct / total, correct, total))

# call test function    
test(loaders_scratch, model_scratch, criterion_scratch, use_cuda)
# Out:
# Test Loss: 4.537276
#
#
# Test Accuracy: 12% (103/836)

# %% [markdown]
# ---
# <a id='step4'></a>
# ## Step 4: Create a CNN to Classify Dog Breeds (using Transfer Learning)
#
# You will now use transfer learning to create a CNN that can identify dog breed from images.  Your CNN must attain at least 60% accuracy on the test set.
#
# ### (IMPLEMENTATION) Specify Data Loaders for the Dog Dataset
#
# Use the code cell below to write three separate [data loaders](http://pytorch.org/docs/master/data.html#torch.utils.data.DataLoader) for the training, validation, and test datasets of dog images (located at `dogImages/train`, `dogImages/valid`, and `dogImages/test`, respectively).
#
# If you like, **you are welcome to use the same data loaders from the previous step**, when you created a CNN from scratch.

# %%
## TODO: Specify data loaders
loaders_transfer = loaders_scratch

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Use transfer learning to create a CNN to classify dog breed.  Use the code cell below, and save your initialized model as the variable `model_transfer`.

# %%
import torchvision.models as models
import torch.nn as nn

## TODO: Specify model architecture 
model_transfer = VGG16

# Freeze features parameters
for param in model_transfer.features.parameters():
    param.requires_grad = False
    
n_inputs = model_transfer.classifier[6].in_features

last_layer = nn.Linear(n_inputs, 133)
model_transfer.classifier[6] = last_layer

if use_cuda:
    model_transfer = model_transfer.cuda()
    
print(model_transfer)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace)
#     (2): Dropout(p=0.5)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace)
#     (5): Dropout(p=0.5)
#     (6): Linear(in_features=4096, out_features=133, bias=True)
#   )
# )

# %% [markdown]
# __Question 5:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  Describe why you think the architecture is suitable for the current problem.

# %% [markdown]
# __Answer:__
#
# I'm using the _features_ layers from `VGG16` as they come, without training them, because it's already capable of recognizing a lot of dog breeds, so there must be relevant features for the dog breed classifier I'm trying to train here. I'm keeping the first two of the `classifier` linear layers, their activations and their dropouts. Finally, I'm modifying the last layer so it outputs 133 probabilities to match the number of classes in this problem.

# %% [markdown]
# ### (IMPLEMENTATION) Specify Loss Function and Optimizer
#
# Use the next code cell to specify a [loss function](http://pytorch.org/docs/master/nn.html#loss-functions) and [optimizer](http://pytorch.org/docs/master/optim.html).  Save the chosen loss function as `criterion_transfer`, and the optimizer as `optimizer_transfer` below.

# %%
criterion_transfer = nn.CrossEntropyLoss()
optimizer_transfer = optim.SGD(model_transfer.parameters(), lr=0.001)

# %% [markdown]
# ### (IMPLEMENTATION) Train and Validate the Model
#
# Train and validate your model in the code cell below.  [Save the final model parameters](http://pytorch.org/docs/master/notes/serialization.html) at filepath `'model_transfer.pt'`.

# %%
# train the model
N_EPOCHS_TRANSFER = 5
model_transfer = train(N_EPOCHS_TRANSFER, loaders_transfer, model_transfer, optimizer_transfer, criterion_transfer, use_cuda, 'model_transfer.pt')
# Out:
# Training model...
# Starting epoch 1/5. Memory allocated: 2189529600
# Epoch: 1 	Training Loss: 1.086838 	Validation Loss: 0.764175 	Memory allocated: 2192294912
# Validation loss decreased (inf --> 0.764175).  Saving model ...
# Starting epoch 2/5. Memory allocated: 2192294912
# Epoch: 2 	Training Loss: 0.780282 	Validation Loss: 0.682966 	Memory allocated: 2192295424
# Validation loss decreased (0.764175 --> 0.682966).  Saving model ...
# Starting epoch 3/5. Memory allocated: 2192294912
# Epoch: 3 	Training Loss: 0.703916 	Validation Loss: 0.685059 	Memory allocated: 2192295424
# Starting epoch 4/5. Memory allocated: 2192295424
# Epoch: 4 	Training Loss: 0.573921 	Validation Loss: 0.623498 	Memory allocated: 2192295424
# Validation loss decreased (0.682966 --> 0.623498).  Saving model ...
# Starting epoch 5/5. Memory allocated: 2192294912
# Epoch: 5 	Training Loss: 0.568527 	Validation Loss: 0.589819 	Memory allocated: 2192295424
# Validation loss decreased (0.623498 --> 0.589819).  Saving model ...

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images. Use the code cell below to calculate and print the test loss and accuracy.  Ensure that your test accuracy is greater than 60%.

# %%
model_transfer.load_state_dict(torch.load('model_transfer.pt'))

data = torch.empty((BATCH_SIZE, 3) + RESIZE_DIMS)
target = torch.empty((133, ))
output = torch.empty((133, ))
loss = torch.empty((1, ))

test(loaders_transfer, model_transfer, criterion_transfer, use_cuda)
# Out:
# Test Loss: 0.566169
#
#
# Test Accuracy: 83% (701/836)

# %% [markdown]
# ### (IMPLEMENTATION) Predict Dog Breed with the Model
#
# Write a function that takes an image path as input and returns the dog breed (`Affenpinscher`, `Afghan hound`, etc) that is predicted by your model.

# %%
### TODO: Write a function that takes a path to an image as input
### and returns the dog breed that is predicted by the model.

# list of class names by index, i.e. a name can be accessed like class_names[0]
data_transfer = {k: loader.dataset for k, loader in loaders_transfer.items()}
class_names = [item[4:].replace("_", " ") for item in data_transfer['train'].classes]

def predict_breed_transfer(img_path):
    img_raw = Image.open(img_path)
    
    transformations = transforms.Compose([
        transforms.Resize(RESIZE_DIMS),
        transforms.ToTensor()
    ])
    
    img = transformations(img_raw)
    img = img[None]
    
    if use_cuda:
        img = img.cuda()
    
    prediction = model_transfer(img)
    
    prob, index = prediction[0, :].max(0)
    return class_names[index]

# %% [markdown]
# ---
# <a id='step5'></a>
# ## Step 5: Write your Algorithm
#
# Write an algorithm that accepts a file path to an image and first determines whether the image contains a human, dog, or neither.  Then,
# - if a __dog__ is detected in the image, return the predicted breed.
# - if a __human__ is detected in the image, return the resembling dog breed.
# - if __neither__ is detected in the image, provide output that indicates an error.
#
# You are welcome to write your own functions for detecting humans and dogs in images, but feel free to use the `face_detector` and `dog_detector` functions developed above.  You are __required__ to use your CNN from Step 4 to predict dog breed.
#
# Some sample output for our algorithm is provided below, but feel free to design your own user experience!
#
# ![Sample Human Output](images/sample_human_output.png)
#
#
# ### (IMPLEMENTATION) Write your Algorithm

# %%
### TODO: Write your algorithm.
### Feel free to use as many code cells as needed.
from matplotlib import pyplot as plt
import matplotlib.image as mpimg 

def sample_dog(breed):
    idx = class_names.index(breed)
    dog_imgs = loaders_transfer['train'].dataset.imgs
    breed_imgs = [img_path for (img_path, class_idx) in dog_imgs if class_idx == idx]
    dog_sample = breed_imgs[0]
    
    return dog_sample

def run_app(img_path):
    ## handle cases for a human face, dog, and neither
    fig = plt.figure(figsize=(8, 8))
    
    breed = predict_breed_transfer(img_path)
    
    img = mpimg.imread(img_path)
    
    fig.add_subplot(1, 2, 1)
    imgplot = plt.imshow(img)
    
    if dog_detector(img_path):
        msg = 'This dog is a {}'.format(breed)
        
    elif face_detector(img_path):
        msg = 'This human looks like a {}'.format(breed)
        
    else:
        msg = 'What are you doing here?'
        
    plt.title(msg) 
    
    fig.add_subplot(1, 2, 2)
    dog_img = mpimg.imread(sample_dog(breed))
    dog_imgplot = plt.imshow(dog_img)
    plt.show()

# %% [markdown]
# ---
# <a id='step6'></a>
# ## Step 6: Test Your Algorithm
#
# In this section, you will take your new algorithm for a spin!  What kind of dog does the algorithm think that _you_ look like?  If you have a dog, does it predict your dog's breed accurately?  If you have a cat, does it mistakenly think that your cat is a dog?
#
# ### (IMPLEMENTATION) Test Your Algorithm on Sample Images!
#
# Test your algorithm at least six images on your computer.  Feel free to use any images you like.  Use at least two human and two dog images.
#
# __Question 6:__ Is the output better than you expected :) ?  Or worse :( ?  Provide at least three possible points of improvement for your algorithm.

# %% [markdown]
# __Answer:__ (Three possible points for improvement)
#
# 1. Use a web interface
# 2. Use only a croped area from the detectors to predict the breed
# 3. Use a bigger batch size (with bigger/multiple GPU)

# %%
## TODO: Execute your algorithm from Step 6 on
## at least 6 images on your computer.
## Feel free to use as many code cells as needed.

## suggested code, below
files = np.array(glob('sampleImages/*'))
for file in files:
    run_app(file)
